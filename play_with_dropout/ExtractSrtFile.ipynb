# %%
"""
Creates readable text file from SRT file.
"""
import re, sys, os

def is_time_stamp(l):
    if l[:2].isnumeric() and l[2] == ':':
        return True
    return False

def has_letters(line):
    if re.search('[a-zA-Z]', line):
        return True
    return False

def has_no_text(line):
    l = line.strip()
    if not len(l):
        return True
    if l.isnumeric():
        return True
    if is_time_stamp(l):
        return True
    if l[0] == '(' and l[-1] == ')':
        return True
    if not has_letters(line):
        return True
    return False

def is_lowercase_letter_or_comma(letter):
    if letter.isalpha() and letter.lower() == letter:
        return True
    if letter == ',':
        return True
    return False

def clean_up(lines):
    """
    Get rid of all non-text lines and
    try to combine text broken into multiple lines
    """
    new_lines = []
    for line in lines[1:]:
        if has_no_text(line):
            continue
        elif len(new_lines) and is_lowercase_letter_or_comma(line[0]):
      #combine with previous line
            line = re.sub('<[^>]+>', '', line)
            new_lines[-1] = new_lines[-1].strip() + ' ' + line
        else:
      #append line
            line = re.sub('<[^>]+>', '', line)
            new_lines.append(line)
    return new_lines

def main(args):
    """
    args[1]: file name
    args[2]: encoding. Default: utf-8.
      - If you get a lot of [?]s replacing characters,
      - you probably need to change file_encoding to 'cp1252'
    """
    file_name = os.path.join('soustitre', args[1])
    file_encoding = 'utf-8' if len(args) < 3 else args[2]
    with open(file_name, encoding=file_encoding, errors='replace') as f:
        lines = f.readlines()
        new_lines = clean_up(lines)
    new_file_name = args[1][:-4] + '.txt'
    directory = 'soustitre'
    path = os.path.join('soustitre', new_file_name)
    try:
        os.makedirs(directory)
    except OSError:
        pass
    with open(path,  'w') as f:
        for line in new_lines:
            f.write(line)
    f.close()
    
def get_all_convos(liste_file):
    convos = []
    for file in list_file:
        path = os.path.join('soustitre', file)
        i = 0
        with open(path, 'r') as f:
            for line in f.readlines():
                line = line.strip('-')
                if i > 3 and i%2 ==0:
                    question = line.strip()
                elif i>3 and i%2==1:
                    answer = line.strip()
                    convos.append([question, answer])
                i +=1
    return convos
# Out:
# Un Garáon appelÇ Papa.txt
# A.Christmas.Prince.2017.23.976.fps.Fr.txt
# A.Christmas.Story.2.2012.NTSC.DVDR-KART3LDVD.Fr.txt
# A.Christmas.Story.Z1.txt
# 2234

# %%
import random
for i in range(10):
    print(random.choice(convos))
# Out:
# ["J'avais besoin de réfléchir.", 'Tu as eu tout le temps.']
# ['les petites choses du quotidien.', 'Prends ça, fripouille neptunienne !']
# ['Mais tu vas toujours en prison.', "On t'enverra des magazines cochons pour soudoyer les matons."]
# ['Ça fait 2 $, Rockefeller.', "C'est pas moi qui ai bousillé une voiture."]
# ['Faites voir.', "C'était dans le gland."]
# ["Comment c'était quoi ?", "Ben,... tu sais bien... quand vous l'avez conçu."]
# ['Le père Noël est déjà passé.', "Je regrette ce que j'ai dit avant de partir, papa."]
# ['Oui, ça va bien, Votre Altesse royale.', "C'est juste votre visage."]
# ["C'est pas vrai !", "Si, c'est vrai."]
# ['cherchant une riposte cinglante.', "Tout ce qu'il trouva fut..."]

# %%
x = 'Kaamelott.Livre5.Tome3.SandM.FR.srt'
#x = 'A.L.Est.De.Moi.(2008).Z2.FR.srt'
file_name = os.path.join('soustitre', x)
new_lines  = []
with open(file_name, encoding='iso-8859-1', errors='replace') as f:
        lines = f.readlines()
        for line in lines:
            line  = re.sub('\x9c', 'oe', t )
            new_lines.append(line)

# %%
for line in new_lines:
    if '' in line:
        print(line)
# Out:
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# Jetez un oeil
#
# ...

# %%
t = re.sub('\x9c', 'oe', t)
t
# Out:
# 'Jetez un oeil\n'
