# %%
chat_()
# Out:
# Bonjour, le bot d'Avicen à ton écoute
# Vous:

# %%
"""
les symboles particulières comme ? ! et . sont supprimé dans la question.
Il faut peut être returner une réponse spécifique si il rencontre plus 1 mot qu'il existe pas dans le corpus
Nous suprimmons également:
  1. Mot qui contient une seule lettre(qui sont suivante des erreurs)
  2. Une fonction unique pour nettoyage tous les données dans train-test et chat
Nous allons traiter tous les mots clés suivant :
km, vitesse, carburant, huile, position, batterie, pression_pneu. Il reste trajet et vin
  
"""
#import sys
#!{sys.executable} -m pip uninstall gtts

#from gtts import gTTS
#from playsound import playsound
#import speech_recognition
from nltk.corpus import stopwords
STOPWORDS = stopwords.words('french')
from nltk.stem import *
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("french", ignore_stopwords = False)
import csv
import re
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import os
import math
import time
from dateparser.search import search_dates
import pandas as pd

def date_time_():
    
    DICT_NUMERO = {'ce':1, 'cette':1, 'un':1, 'une':1, 'deux':2, 'trois':3,\
                   'quatre':4, 'cinq':5, 'six':6, 'sept':7,\
              'huit':8, 'neuf':9, 'dix':10, 'onze':11, 'douze':12, 'treize':13,'quartoze':14,\
               'quinze':15, 'seize':16, 'dix-sept':17,'dix sept':17, 'dix huit':18, \
               'dix-huit':18, 'dix-neuf':19, 'vingt':20, 'ving et un':21, 'trente':30, 'quarante':40,\
                  'quarante cinq':45, 'soixante':60}
    DICT_TEMPS = {'heure':1, 'matin':4, 'après-midi':2,  'journée':24,  'jour':24, \
              'mois':30*24, 'semaine':7*24, \
              'an':24*365, 'année':24*365, 'minute': 1/60}
    DICT_COMPLET_TEMPS = {}
    for temps in DICT_TEMPS:
        for numéro in DICT_NUMERO:
            key1 = numéro + ' '+temps
            key2 = str(DICT_NUMERO[numéro]) + ' ' +temps
            value = DICT_NUMERO[numéro]*DICT_TEMPS[temps]
            DICT_COMPLET_TEMPS[key1] = value
            DICT_COMPLET_TEMPS[key2] = value
    DICT_FOR_SPECIAL_CASE = {'aujourd\'hui':8, 'hébdomadaire':7*24, 'annuel': 365*24, \
                           'hier': 24, 'avant-hier': 48, 'annuelle': 365*24 , 'actuellement':1/2,\
                            'maintenant':1/2}
    DICT_COMPLET_TEMPS['#cas_particulier#'] = DICT_FOR_SPECIAL_CASE
    DICT_COMPLET_TEMPS['avant hier'] = 72
    DICT_COMPLET_TEMPS['semaine dernière'] = 24*7
    return DICT_COMPLET_TEMPS

def construct_list_city():
    #import csv
    liste_ville =[]
    with open('data/villes_france.csv') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            liste_ville.append(row[2])
        for ville in liste_ville:
            if len(ville) <4:
                liste_ville.remove(ville)
    return liste_ville

def _find_right_time(question, Dict):
    
    list_ = ['?', '.', ' ', '\n', '!']
    for symbol in list_:
        question = question.lower().strip(symbol)
    list_word = question.split()
    word_ = None
    list_ = []
    if len(list_word) < 2:
        return None, None 
    for word in list_word:
        if word_ is not None:
            list_.append(str(word_)+' '+str(word))  
        word_ = word
    for key in Dict:
        for word in  list_:
            if key == word:
                return Dict[key], key
    for word in Dict['#cas_particulier#']:
        for word2 in question.split():
            if word2 == word:
                return Dict['#cas_particulier#'][word], word       
    return None, None


def _find_right_geography(question, Dict):
    """
    Nous cherchons une ville, un département dans le dictionnaire pour retourner soit
    ce nom de ce lieu, soit ses coordonnées correspondance. Le retour de ce donnée dépend 
    de quel façon nous allons traiter avec cette information.
    
    """
    list_ = ['?', '.', '\n', '!', ',']
    for symbol in list_:
        question = question.replace(symbol, '') 
    list_geography = []
    for word in question.split():
        if word.lower() !=word:
            word1 = word.lower()
            if word1 in Dict:
                list_geography.append(word)
    if len(list_geography) >0:
        return list_geography
    else:
        return None

def list_variable():
    """
    list_var is to manually complete """
    list_var = []
    if len(list_var) >0:
        return list_var
    else:
        return None

def _normalized_table():
    """
    return a data frame with new name
    """
    import pandas as pd
    df = pd.read_csv('fleet_donnees.csv', sep = ';')
    variable_names = list_variable()
    if variable_names ==None:
        return df
    else:
        name = list(df)
        dict_name = {name[i]: variable_names[i] for i in range(len(name))}
        df = df.rename(index= str, columns = dict_name)
        return df

def find_right_time_from_table(time, df):
    """
    given time found from a question, match it with the time given in table
    This depend on format of time in table.
    
    """
    return None
    
    
def clearing_word(word):
    word = re.sub('\x8e', 'é', word)
    word = re.sub('\x88', 'à', word)
    word = re.sub('\x9d', 'ù', word)
    word = re.sub('\x8f', 'è', word)
    word = re.sub('\x9e', 'û', word)
    word = re.sub('\x90', 'ê', word)
    word = re.sub('\x99', 'ô', word)
    word = re.sub('\x94', 'î', word)
   # word = re.sub('\x8f', 'è', word)
    word = re.sub('\x8d', 'ç', word)
    word = re.sub('õ', '', word)
    word = re.sub('Ê', '', word)
    word = re.sub('[?,.,!, \,,  %]', '', word)
    if word == 'û' or word == 'v' or word == 'é':
        word = ''
    if word =="2017êles":
        word = "2017"
    if "ênox" in word:
        word ="nox"
    return word


def clear_line(pharse):
    """
    Arg: string
    Return: string
    """
    dict_manuel = dict_manuelle()
    pharse_ =[]
    for words in pharse.strip().strip('?').strip('.').strip('!').lower().split(' '):
        for word in words.split('-'):
            for word_ in word.split('\''):
                word_ = clearing_word(word_)
                word_ = stemmer.stem(word_)
        #if word_ not in stop_word and len(word_) >1:       
        pharse_.append(word_)  
        for i in range(len(pharse_)):
            for line in dict_manuel:
                if pharse_[i] in line:
                    pharse_[i] = line[0]
    return ' '.join(pharse_)

def stemmer_line(line):
    return ' '.join([stemmer.stem(word) for word in line.split()])

def prepareData(PAIRS):
    pairs_trains, pairs_tests = [], []
   # PAIRS.extend(pairs1)
    index_train = random.sample(range(len(PAIRS)), int(len(PAIRS)*0.80))
    for i in range(len(PAIRS)):
        if i in index_train:
            pairs_trains.append(PAIRS[i])
        else:
            pairs_tests.append(PAIRS[i])
    print("Read %s sentence pairs of training set" % len(pairs_trains))
    print("Read %s sentence pairs of test set" % len(pairs_tests))
    return pairs_trains, pairs_tests

def get_all_convos(stopwords, file):
    
    convos = []
    questions_to_print = []
    liste_file = [file]
    list_of_word = []
    for file in liste_file:
        with open(file) as f:
            i=0
            for line in f:
                if i%2==0:
                    question = str(line)
                    if '++++' in question:
                         question = question[8:]
                    question_ = question.strip().strip('!').strip('?').strip('.')
                    questions_to_print.append(question_)
                    question = clear_line(question)
                else:
                    answer = str(line)
                    if '++++' in answer:
                        answer = answer[8:].strip()
                    convos.append([question, answer])
                i+=1
        f.close()
        good_index = []
        convos_ = []
        for i in range(len(convos)):
            if convos[i][0] not in convos_:
                convos_.append(convos[i][0])
                good_index.append(i)
            
    
    return [convos[i] for i in good_index], [questions_to_print[i] for i in good_index]


def get_questions_for_classification():
    
    file1 = 'data/trains_sujet.txt'
    file2 = 'data/trains_hors_sujet.txt'
    liste_file = [file1, file2]
    index = 0
    for file in liste_file:
        questions = []
        with open(file) as f:
            i = 0 
            for line in f:
                if i%2 == 0:
                    question = str(line).strip().strip('?').strip('.').strip('!')
                    if '++++' in question:
                         question = question[8:]
                    questions.append(question)
                i += 1
        if index == 0:
            questions_sujet = questions
            index += 1
        else:
            questions_hors = questions
        f.close()
    return questions_sujet, questions_hors


def get_all_questions_to_print(file):
    
    convos = []
    liste_file = [file]
    list_of_word = []
    for file in liste_file:
        with open(file) as f:
            i=0
            for line in f:
                if i%2==0:
                    question = str(line)
                    if '++++' in question:
                         question = question[8:]
                    question = question.strip()
                    convos.append(question)
                i+=1
        f.close()
        indexes = []
        index = 0
    for question in convos:
        question = clear_line(question)
        if len(question) !=0:
                indexes.append(index)
        index +=1
    return [convos[i] for i in indexes]

def get_list_words(convos):
    list_words =[]
    for pair in convos:
        for word in pair[0].split():
            if word not in list_words:
                list_words.append(word)
    print('There are {} words in corpus:'.format(len(list_words)))
    return list_words
                

def simulation_pairs():
    
    DIRECT_VARIABLE = ['vitesse', 'batterie', 'position', 'km']
    BORDE = {'MAX': ['plus grand', 'plus grande', 'plus grands', 
         'plus grandes',
         'plus vite', 'max', 'maximum', 'maximal', 'maximaux', 'maximale',
        'plus haut', 'plus haute', 'plus hautes', 'plus hauts',  
        'plus élevé', 'plus élevée', 'plus élevés', 'plus élevées'], 
         'MIN':['moins grand', 'moins grande', 'moins grands','moins grandes',
        'plus petit', 'plus petite', 'plus petits', 'plus petites','plus faible', 'plus faibles', 
         'min', 'minimal', 'minimale', 'minimales', 'minimaux','moins vite', 
         'moins élevé', 'moins élevée', 'moins élevés', 'moins élevées'],
        'MOYENNE': ['moyenne', 'moyen', 'moyennement']
        }
    COMPLEX_ANALYSIS = ['problème', 'problèmes', 'erreurs', 'erreur', 'danger']
    PAIRS = []
    question_for_simulation = ['quels véhicules ont', 'quel véhicule', 'quelle voiture', 'quelles voitures']
    reponse_for_simulation = 'véhicule'
    for borde in BORDE:
        for word in BORDE[borde]:
            for direct_variable in DIRECT_VARIABLE:
                for question_f_s in question_for_simulation:
                    if direct_variable !='position':
                        question= question_f_s+' '+direct_variable + ' '+ word
                        key0 = '#id#'
                        key1 = '#'+direct_variable+'#'
                        key2 = '#'+borde +'#'
                        reponse = reponse_for_simulation +' '+key0+ ' '+ key1+ ' '+ key2
                        PAIRS.append([question,reponse])

    question_for_simulation = ['', 'quel véhicule a', 'quelle voiture a', 'quelles voitures ont', 'il y a']
    reponse_for_simulation = 'véhicule' 
    for direct_variable in DIRECT_VARIABLE:
        for complex_analysis in COMPLEX_ANALYSIS:
            for question_f_s in question_for_simulation:
                #if direct_variable !='position':
                      question= question_f_s+' '+complex_analysis + ' '+ direct_variable
                      key0 = '#id#'
                      key1 = '#'+direct_variable+'#'
                      key2 = '#'+ complex_analysis +'#'
                      reponse = reponse_for_simulation +' '+key0+ ' '+ key2 +' '+ key1
                      PAIRS.append([question,reponse])
    return PAIRS

def clear_pairs_trains(pairs_trains):
    questions = []
    index = []
    for i in range(len(pairs_trains)):
        if  pairs_trains[i][0] not in questions:
            index.append(i)
            questions.append(pairs_trains[i][0])
    return [pairs_trains[i] for i in index]

def tf_idf(word, doc):
    """
    Nous avons utilisé une normalisation pour TF-IDF"""
    tf, df = 0, 0
    len_doc = len(split_words(doc))
    value_word = 1/math.sqrt(len_doc)
    value_word = math.sqrt(value_word)
    if word in str(doc):
        tf = value_word
    for doc_ in DATA:
        if word in str(doc_):
            df+=1
    if df>0:
        return tf*math.log(len(DATA)/(df), 10)
    else:
        return 0
    
def tf_idf_modified(word, doc, k):
    """
    Nous avons utilisé une normalisation pour TF-IDF"""
    tf, df = 0, 0
    len_doc = len(split_words(doc))
    value_word = 1/math.sqrt(len_doc)
    value_word = math.sqrt(value_word)
    len_word = len(word.split())
    #len_word *= len_word
    if word in str(doc):
        tf = value_word*k/len_word
    for doc_ in DATA:
        if word in str(doc_):
            df+=1
    if df>0:
        return tf*math.log(len(DATA)/(df), 10)
    else:
        return 0

def dict_for_all_doc(data): 
    """
    return hold data's dictionary"""
    dict_ = {}
    for doc in data:
        list_word_ = split_words(doc)    
        dict_[doc] = {word: tf_idf_modified(word, doc, K) for word in list_word_}
    return dict_
    
def dict_doc_score_for_classif(doc, sujet): 
    """
    We return score of all one words and all two consequent words"""

    list_word_ = split_words(doc)    
    return {word: tf_idf_for_classif(word, doc, sujet) for word in list_word_}

   
def split_words(doc):
    """
    Return word and term, for example, if document of 5 words, 
    it will return 5+4+3 words and terms"""
    list1 = doc.split()
    list2 = []
    for word in list1:
        list2.append(word)
    for i in range(len(list1)-1):
        word = list1[i]+ ' '+list1[i+1]
        list2.append(word)
    if len(list1)>2:
        for i in range(len(list1)-2):
            word = list1[i]+' '+list1[i+1]+list1[i+2]
            list2.append(word)
    return list2
        
        
def get_key_list(pairs_trains):
    
    dict_ = dict_manuelle()
    KEY_LIST = []
    KEY_LIST_ = []
    for pair in pairs_trains:
        for word in pair[1].split():
            if '#' in word:
                word = re.sub('#', '', word)
                if word not in KEY_LIST:
                    KEY_LIST.append(word)
    for key in KEY_LIST:
        key = stemmer.stem(key)
        if key not in KEY_LIST_ and '_' not in key:
            KEY_LIST_.append(key)
    KEY_RETURN = []
    for key in KEY_LIST_:
        boolean = False
        for list_ in dict_:
            if key in list_:
                KEY_RETURN.append(list_[0])
                boolean = True
                break
        if not boolean:
            KEY_RETURN.append(key)
    #for list_ in dict_:
       # if list_[0] not in KEY_RETURN:
        #    KEY_RETURN.append(list_[0])       
    return KEY_RETURN
        

def find_right_index(new_doc,DICT, méthode = 'normal'):
    
    index=0
    biggest_score = score_by_new_doc(new_doc, QUESTION_TO_TRAINS[0],DICT, méthode)
    for i in range(len(QUESTION_TO_TRAINS)):
        boolean1 = score_by_new_doc(new_doc, QUESTION_TO_TRAINS[i], DICT, méthode) >biggest_score
        boolean2 = score_by_new_doc(new_doc, QUESTION_TO_TRAINS[i], DICT, méthode) == biggest_score
        boolean3 = len(QUESTION_TO_TRAINS[index]) >len(QUESTION_TO_TRAINS[i])
        if boolean1 or (boolean2 and boolean3):
            biggest_score = score_by_new_doc(new_doc, QUESTION_TO_TRAINS[i],DICT, méthode)
            index = i
    précision, rappel = precision_recall(new_doc, QUESTION_TO_TRAINS[index])
    #if biggest_score ==0 or précision <0.2 or rappel<0.2:
     #   for question in QUESTION_TO_TRAINS:
      #      if '_return_' in question:
       #         try:
        #            index = QUESTION_TO_TRAINS.index(question)
         #       except ValueError:
          #          index = -1
    return index

def reformule_question_if_need(new_question, good_question):
    
    if 'to_return' in good_question:
        return True
    score1 = score_by_new_doc(new_question, good_question, DICT)
    score2 = 0
    for word in Dict_of_methode[good_question]:
        score2 += Dict_of_methode[good_question][word]
    if score1/score2 > 0.6:
        return  True
    else:
        return  False


def test(DICT, méthode, train =False):
    
    if not train:
        index_to_print = random.sample(range(len(pairs_tests)), 20)
        #loss_total = 0
        for i in range(len(pairs_tests)):
            index = find_right_index(pairs_tests[i][0], DICT, méthode)
            #loss = _evaluate_by_right_word(pairs_trains[index][1], pairs_tests[i][1])
            #loss_total +=loss
            if i in index_to_print:
                print(pairs_tests[i])
                print(pairs_trains[index][1])
        print('-'*80)
       # print('ACCURACY=', 1-loss_total/len(pairs_tests))
    if  train:
        #loss_total = 0
        #index_to_print = random.sample(range(len(pairs_trains)), 20)  
        list_of_bad_prediction = []
        i0 = 0
        for i in range(len(pairs_trains)):
            index = find_right_index(pairs_trains[i][0], DICT, méthode)
            #loss = _evaluate_by_right_word(pairs_trains[index][1], pairs_trains[i][1])
            #loss_total +=loss
            if index != i :
                i0 +=1
                print(pairs_trains[i])
                print(pairs_trains[index][1])
        print('-'*80)
        #print('ACCURACY=', 1-loss_total/len(pairs_trains))
        print('Il y a {} erreurs d\'indexes parmis {} prédictions'.format(i0, len(pairs_trains)))

        
def test_without_print(DICT, méthode, train =False):
    
    if not train:
        loss_total = 0
        for i in range(len(pairs_tests)):
            index = find_right_index(pairs_tests[i][0], DICT, méthode)
            loss = _evaluate_by_right_word(pairs_trains[index][1], pairs_tests[i][1])
            loss_total +=loss
        print('-'*80)
        print('ACCURACY=', 1-loss_total/len(pairs_tests))
    if  train:
        loss_total = 0
        index_to_print = random.sample(range(len(pairs_trains)), 20)   
        for i in range(len(pairs_trains)):
            index = find_right_index(pairs_trains[i][0], DICT, méthode)
            loss = _evaluate_by_right_word(pairs_trains[index][1], pairs_trains[i][1])
            loss_total +=loss
        print('-'*80)
        print('ACCURACY=', 1-loss_total/len(pairs_trains))

def change_subjet_of_question(question):
    dict_ = {'ton':'mon', 'ta':'ma', 'votre':'mon', 'tes':'mes', 'mon':'ton', \
            'ma':'ta', 'mes':'tes', 'tu': 'je', 'moi':'toi', 'je':'tu', 'toi':'moi',\
            'vous':'je'}
    question_ = []
    for word in question.lower().split():
        if word in dict_:
            word = dict_[word]
        question_.append(word)
    return ' '.join(question_)
        
def chat(méthode='normal'):
    
    print('Bonjour, C\'est le bot d\'Avicen, pose tes questions, s\'il te plaît!')
    path = 'processed/chat_tfidf.txt'
    f =  open(path, 'a+') 
    while True:
            line = str(input('Vous: '))
            list_city = _find_right_geography(line, CITY_LIST)
            line = line.lower().strip().strip('?').strip('.')
            time, time_word = _find_right_time(line, COMPLET_DICT_TIME)
            if time_word is not None:
                line = line.replace(time_word, '')
            if list_city is not None:
                for city in list_city:
                    line = line.replace(city, '')
            LINE = clear_line(line)
            unknown_word =0
            for word in LINE.split():
                if word not in LIST_OF_WORDS:
                    unknown_word += 1
            #if unknown_word > 1:
             #   print('Désolé, je ne comprends pas ta question, peux tu la reformuler s\'il te plaît?')
              #  continue
            if len(line) !=0:
                index= find_right_index(LINE, DICT, méthode)
                good_question = QUESTION_TO_TRAINS[index]
                if not reformule_question_if_need(LINE, good_question):
                    get_answer = str(input('Tu veux demander: {}?  |'.format(questions_sujet[index])))
                    if 'non' in get_answer.lower():
                        print('Peux tu reformuler ta question s\'il te plaît?')
                        continue
                if time == None and list_city == None:
                     print('bot: ', pairs_trains[index][1])
                elif list_city ==None:
                    print('Bot: {}, {}'.format(time_word, pairs_trains[index][1]))
                elif time == None:
                    cities = ' '.join(list_city)
                    print('Bot: À {}, {}'.format(cities, pairs_trains[index][1]))
                else:
                    cities = ' '.join(list_city)
                    print('Bot: À {}, {}, {}'.format(cities, time_word, pairs_trains[index][1]))
                f.write('VOUS ++++ '+line+'\n')
                f.write('BOT ++++ '+pairs_trains[index][1]+'\n')
            
            else:
                f.close()
                break 

def precision_recall(lstcomp, lstref):
    
    card_intersec = 0.0 # force à utiliser la division non entière
    for t in set(lstcomp) :
        card_intersec += min(lstref.count(t), lstcomp.count(t))
    if len(lstcomp)==0:
        precision =1
    else:
        precision = card_intersec/len(lstcomp)
    if len(lstref)==0:
        rappel = 1
    else:
        rappel = card_intersec/len(lstref)
    return (precision, rappel)


def calcul_precision_recall_(train = False): 
    
    if not train:
        total_precision, total_recall = 0, 0
        len_ = len(convos_test)
        index_to_print = random.sample(range(len_), 30)
        for i in range(len(questions_test)):
            question = convos_test[i][0]
            index = find_right_index_(question)
            answer = convos_train[index][1]
            good_answer = convos_test[i][1]
            precision, recall = precision_recall\
            (answer, good_answer)
            total_precision  += precision
            total_recall     += recall
            #if i in index_to_print:
            #    print('raw questions: {}. precision {}'.format( questions_test[i], precision))
             #   print('answer: {}. good answer: {} '.format(answer, good_answer))
        #print('-'*80)
        total_precision = total_precision/len_
        total_recall = total_recall/len_      
        F = 2*total_precision*total_recall/(total_precision+total_recall)
        print('ON TEST, WE HAVE: PRECISION = {:.5f},  RECALL = {:.5f}, F_MESURE = {:.3f} '\
              .format(total_precision, total_recall,F))
        print()
    if  train:       
        total_precision, total_recall = 0, 0
        len_total = len(convos_train)
        for i in range(len(convos_train)):
            question = convos_train[i][0]
            index = find_right_index_(question)
            answer = convos_train[index][1]
            good_answer = convos_train[i][1]
            precision, recall = precision_recall\
            (answer, good_answer)
            total_precision  += precision
            total_recall     += recall
        print('-'*80)
        total_precision = total_precision/len_total
        total_recall = total_recall/len_total     
        F = 2*total_precision*total_recall/(total_precision+total_recall)
        print('ON TRAINS, WE HAVE PRECISION = {:.5f},  RECALL = {:.5f}, F_MESURE = {:.3f} '\
              .format(total_precision, total_recall,F))
        

def return_F_score(): 
    
        total_precision, total_recall = 0, 0
        len_ = len(convos_test)
        for i in range(len(questions_test)):
            question = convos_test[i][0]
            index = find_right_index_(question)
            answer = convos_train[index][1]
            good_answer = convos_test[i][1]
            precision, recall = precision_recall\
            (answer, good_answer)
            total_precision  += precision
            total_recall     += recall
        total_precision = total_precision/len_
        total_recall = total_recall/len_     
        F = 2*total_precision*total_recall/(total_precision+total_recall)
        return F
 
    
def chatting_with_corpus():

    path = 'processed/chat_tfidf.txt'
    i = 0
    questions = []
    with open(path, 'r') as f:
        for line in f:
            if i%2 ==0:
                line = line[8:]
                line = line.strip().strip('-').strip('+')
                questions.append(line)
            i +=1
    f.close()
    good_index = []
    questions_ = []
    index = 0
    for question in questions:
        question = clear_line(question)
        if question not in questions_:
            questions_.append(question)
            good_index.append(index)
        index += 1
    questions_clean = [questions[i] for i in good_index]
    for line in questions_clean:
            print('Humaine: ', line)
            time, time_word = _find_right_time(line, COMPLET_DICT_TIME)
            list_city = _find_right_geography(line, CITY_LIST)
            if time_word is not None:
                line = line.replace(time_word, '')
            if list_city is not None:
                for city in list_city:
                    line = line.replace(city, '')
            LINE = clear_line(line)
            unknown_word =0
            for word in LINE.split():
                if word not in LIST_OF_WORDS:
                    unknown_word += 1
            if unknown_word > 1:
                print('Désolé, je ne comprends pas ta question, peux tu la reformuler s\'il te plaît?')                    
                print()
                continue
            if len(line) !=0:
                index= find_right_index_(LINE)
                if time == None and list_city == None:
                     print('Bot: ', convos_train[index][1])
                elif list_city ==None:
                    print('{}, {}'.format(time_word, convos_train[index][1]))
                elif time == None:
                    cities = ' '.join(list_city)
                    print('À {}, {}'.format(cities, convos_train[index][1]))
                else:
                    cities = ' '.join(list_city)
                    print('À {}, {}, {}'.format(cities, time_word, convos_train[index][1]))
            print()
               
def dict_manuelle():
    """
    return la liste des listes des synonymes"""
    list_ = []
    dict_ = {}
    dict_['voiture'] = ['voiture', 'véhicule']
    dict_['km'] = ['km', 'kilomètrage', 'kilométrage', 'distance', 'kilomètre']
    dict_['essence'] = ['essence', 'carburant', 'énergie']
    dict_['roule'] = ['roule', 'roulent', 'marche', 'marcher', 'circule', 'circulent', 'circulation']
    dict_['bien'] = ['bien', 'bonne', 'good', 'excellent', 'parfait', 'beau', 'ok']
    dict_['min']  = ['min', 'minimum', 'minimal']
    dict_['pneu'] = ['pneumatique', 'pneu', 'pneus']
    dict_['pouquoi'] = ['cause', 'pourquoi', 'raison', 'motif']
    dict_['stupid'] = ['stupid', 'con', 'idiot', 'bête', 'imbécile']
    dict_['connaître'] = ['connaître', 'connaitre', 'savoir', 'comprendre',\
                          'connaisance', 'connais', 'connaîs', 'sais', 'savez']
    dict_['problème']  = ['problème', 'difficulté', 'danger', 'ennui', 'dangers']
    dict_['erreur'] = ['faute', 'erreur']
    dict_['arrêt'] = ['arrêt', 'arrêter', 'stopper', 'immobilisé', 'immobiliser', 'immobile', 'paralisé']
    dict_['disponible'] = ['disponible', 'disponibilité', 'libre']
    dict_['abimer'] = ['abîmer', 'hors service', 'cassé', 'endommager', 'abîmé']
    dict_['boitier'] = ['boitier', 'boîtier', 'boîte']
    dict_['frein'] = ['frein', 'freinage', 'freiner']
    dict_['parcouru'] = ['parcouru', 'parcourus', 'parcourir']
    dict_['peux'] = ['peux', 'pouvoir', 'pourrais']
    dict_['veux'] = ['veux', 'vouloir', 'veut', 'voulais', 'voudrais', 'souhaiter', 'souhaite']
    dict_['fait'] = ['fait', 'fais', 'faire', 'faites']
    dict_['fort'] = ['fort', 'puissant', 'robuste', 'solide']
    dict_['grand'] = ['grand', 'gross', 'élevé', 'haut', 'haute']
    dict_['mal'] = ['mal', 'mauvais', 'souci']
    dict_['changer'] = ['modifier', 'modification', 'changer', 'changement']
    dict_['avoir'] = ['as', 'obtenir', 'avoir', 'posséder', 'disposer']
    dict_['peur']  = ['peur', 'craint']
    dict_['placer'] = ['placer','installer']
    dict_['nombre'] = ['nombre', 'combien', 'quantité']
    dict_['aider']  = ['aider', 'aide', 'soutien', 'soutenir']
    dict_['question'] = ['question', 'demande']
    dict_['information'] = ['information', 'infos', 'renseignement', 'indictation',\
                            'informer', 'renseigner','indiquer']
    dict_['usé'] = ['usé', 'usure', 'vieux', 'vieille', 'fatigué']
    dict_['réduire']  = ['réduire', 'réduction', 'abaisser', 'diminuer', 'diminution']
    dict_['présent']  = ['présent', 'maitenant', 'actuel', 'actuellement']
    dict_['suivre']   = ['suivre', 'observer', 'surveiller', 'poursuivre']
    dict_['aller']    = ['aller', 'vas', 'vais', 'va']
    dict_['échanger'] = ['échanger', 'estimer', 'échangement', 'estimation',\
                         'évaluer', 'calculer','évaluation'\
                        , 'mesurer']
    dict_['taux']    = ['taux', 'pourcentage']
    dict_['ampoule'] = ['ampoule', 'feux', 'feu']
    for key in dict_:
        l = []
        for word in dict_[key]:
            l.append(stemmer.stem(word))
        list_.append(l)
    return list_

    
                
def chatting_with_test_corpus():
    
    path = 'test.txt'
    questions = []
    with open(path, 'r') as f:
        for line in f:
                line = line.strip()
                questions.append(line)
    f.close()
    questions_clean = []
    for question in questions:
        if question not in questions_clean:
            questions_clean.append(question)
    for line in questions_clean:
            line1 = line
            time, time_word = _find_right_time(line, COMPLET_DICT_TIME)
            list_city = _find_right_geography(line, CITY_LIST)
            if time_word is not None:
                line = line.replace(time_word, '')
            if list_city is not None:
                for city in list_city:
                    line = line.replace(city, '')
            LINE = clear_line(line)
            unknown_word =0
            print('Vous: ', line1)
            for word in LINE.split():
                if word not in LIST_OF_WORDS:
                    unknown_word += 1
            if unknown_word > 1:
                print('Bot: Désolé, je ne comprends pas ta question, peux tu la reformuler s\'il te plaît?')
                print()
                continue
            if len(line) !=0:
                index= find_right_index(LINE, DICT, méthode)
                if time == None and list_city == None:
                     print('Bot: ', pairs_trains[index][1])
                elif list_city ==None:
                    print('Bot: {}, {}'.format(time_word, pairs_trains[index][1]))
                elif time == None:
                    cities = ' '.join(list_city)
                    print('Bot: À {}, {}'.format(cities, pairs_trains[index][1]))
                else:
                    cities = ' '.join(list_city)
                    print('Bot: À {}, {}, {}'.format(cities, time_word, pairs_trains[index][1]))
               
                LINE = clear_line(line)   
                index = find_right_index(LINE, DICT, METHODE[0])
                #print('YOU: ', line)
                #print('BOT: ', pairs_trains[index][1])
                print()
            

def get_all_and_all_convos():
    convos = []
    file1 = 'data/convos27juin_test.txt'
    file2 = 'data/convos27juin_train.txt'
    files = [file1, file2]
    for file in files:
        with open(file, 'r') as f:
            i=0
            for line in f:
                if i%2==0:
                    question = line.strip()
                    if '++++' in question:
                         question = question[9:]
                else:
                    answer = line.strip()
                    if '++++' in answer:
                        answer = answer[9:]
                    convos.append([question, answer])
                i+=1
        f.close()
    return convos


def get_all_convos_in_movies():
    convos = []
    raw_questions = []
    raw_convos = []
    for root, dirs, files in os.walk("soustitre"):
        for file in files:
            if file.endswith(".txt"):
                path = os.path.join(root, file)
                i = 0
                with open(path, 'r') as f:
                    get_ = False
                    for line in f.readlines():
                        line = line.strip('-')
                        if i > 3:
                            if '?' in line and get_ == False:
                                question = line.strip()
                                get_ = True
                            else:
                                if get_ == True:
                                    answer = line.strip()
                                    convos.append([clear_line(question), answer])
                                    raw_convos.append([question, answer])
                                    raw_questions.append(question)
                                    get_ = False
                          
                        i +=1
    index_of_train = random.sample(range(len(convos)), int(.8*len(convos)))
    raw_questions = [raw_questions[i] for i in index_of_train]
    pairs_trains = [convos[i] for i in index_of_train]
    pairs_tests = [convos[i] for i in range(len(convos)) if i not in index_of_train]
    return pairs_trains, pairs_tests, raw_questions, raw_convos


    
def dict_of_all_score_(data, KEY_LIST, sujet):
    """
    return score of all word in all doc"""
    DICT = {}
    for doc in data:
        DICT[doc]=dict_doc_score_(doc,KEY_LIST, sujet)
    return DICT 



def find_right_index_(new_doc):
    

    index=0
    biggest_score = score_by_new_doc_(new_doc, DATA[0],dictionary)
    for i in range(len(DATA)):
        boolean1 = score_by_new_doc_(new_doc, DATA[i], dictionary) > biggest_score
        boolean2 = score_by_new_doc_(new_doc, DATA[i], dictionary) == biggest_score
        boolean3 = len(DATA[index]) >len(DATA[i])
        if boolean1 or (boolean2 and boolean3):
            biggest_score = score_by_new_doc_(new_doc, DATA[i], dictionary)
            index = i
    if biggest_score == 0:
        index = random.choice([i for i in range(len(DATA))])
    return index



        



def request_missing_infos(new_question, good_question, dict_):
    
    if 'to_return' in good_question:
        return True
    score1 = score_by_new_doc_(new_question, good_question, dict_)
    score2 = 0
    for word in dict_[good_question]:
        score2 += dict_[good_question][word]
    if score1/score2 > 0.6:
        return  True
    else:
        return  False
    
def to_print_answer(line):
    line = str(line)
    first = line[0]
    line = first.upper()+ line[1:]
    if line[-1] not in ['?','.','!']:
        line = line+'.'
    line = line.strip(' ')
    return line
    
def chat_(): 
    print('Bonjour, le bot d\'Avicen à ton écoute')
    path = 'processed/chat_tfidf.txt'
    f =  open(path, 'a+') 
    while True:
            line = str(input('Vous: '))
            if len(line) < 2:
                break
            time, time_word = _find_right_time(line, COMPLET_DICT_TIME)
            list_city = _find_right_geography(line, CITY_LIST)
            if time_word is not None:
                line = line.replace(time_word, '')
            if list_city is not None:
                for city in list_city:
                    line = line.replace(city, '')
            LINE = clear_line(line)
            unknown_word =0
            for word in LINE.split():
                if word not in LIST_OF_WORDS:
                    unknown_word += 1
            if unknown_word > 1:
                print('Désolé, je ne comprends pas ta question, peux tu la reformuler s\'il te plaît?')                    
                print()
                continue
            if len(line) !=0:
                index= find_right_index_(LINE)
                if time == None and list_city == None:
                     print('Bot: ', convos_train[index][1])
                elif list_city ==None:
                    print('{}, {}'.format(time_word, convos_train[index][1]))
                elif time == None:
                    cities = ' '.join(list_city)
                    print('À {}, {}'.format(cities, convos_train[index][1]))
                else:
                    cities = ' '.join(list_city)
                    print('À {}, {}, {}'.format(cities, time_word, convos_train[index][1]))
                
    
def dict_doc_score_(doc, KEY_LIST, sujet): 
    """
    We return score of all one words and all two consequent words"""

    list_word_ = split_words(doc)    
    return {word: tf_idf_(word, doc, KEY_LIST, sujet) for word in list_word_}
   

    
def score_by_new_doc_(new_doc, doc, DICT):
    
    list_word_in_doc = split_words(new_doc)
    score = 0
    for word in list_word_in_doc:
            if word in DICT[doc]:
                 score += DICT[doc][word]
    return score


def tf_idf_standard(word, doc):
    
    df = 0
    doc_split = split_words(doc)
    if word in doc_split:
        tf = 1
    else:
        tf = 0
    for doc_ in DATA:
        if word in doc_:
            df+=1
    if df >0:
        return tf*math.log(len(DATA)/df, 10)
    else:
        return 0
    
def dict_of_entropy_for_all_terms(terms, K):
    """
    Nous utilisons la méthode donné dans Class Specific TF-IDF Boosting 2018
    K is a tuning parameter of method"""
    dictionnary_terms ={}
    H_max =0
    for term in terms:
        H = 0
        df = 0
        for data2 in DATA:
            if term in data2:
                df+=1
        for data in DATA:
            if term in data:
                tf_idf = - 1/df*math.log(1/df, 2)
            else:
                tf_idf = 0
            H += tf_idf
        if H > H_max:
            H_max = H
        dictionnary_terms[term] = H
    for term in terms:
        dictionnary_terms[term] = (H_max - dictionnary_terms[term])/(H_max*K)
    return dictionnary_terms

def dict_of_all_doc_by_new_method(K):
    
    """
    This will be the dictionnary which is the heart of method"""
    dict_of_new_method = {}
    terms = get_all_terms()
    dictionnary_terms = dict_of_entropy_for_all_terms(terms, K)
    for doc in DATA:
        terms_of_this_doc = split_words(doc)
        dict_term_for_this_doc = {term: tf_idf_standard(term, doc)+dictionnary_terms[term]\
                                  if tf_idf_standard(term, doc) >0 else 0\
                                  for term in terms_of_this_doc}
        dict_of_new_method[doc] = dict_term_for_this_doc
    return dict_of_new_method

def get_all_terms():
    """
    return all terms for training
    """
    all_terms = []
    for data in DATA:
        all_terms.extend(split_words(data))
    return all_terms
        
    
    
def get_best_parameter():
    
    start = time.time()
    K = [1/4000, 1/1000, 1/256, 1/64]
    k_best = 1
    F_best = 0
    for k in K:      
        dictionary =  dict_of_all_doc_by_new_method(k)
        F_score = return_F_score()
        print('k= {}, F score = {}'.format(k, F_score))
        if F_score >F_best:
            F_best = F_score
            k_best = k
    print('best score is {} and best k is {}'.format(F_best, k_best))
    print('running time is ', int(time.time()-start), 's.')
    return k_best, F_best
        
        
        


def data_processed():
    """
    Traiter et retourner les conversations avec les questions bien nettoyées
    les questions sans nettoyer et le couple pour test
    """
    convos1, questions1 = get_all_convos(STOPWORDS,'data/trains_sujet.txt')
    convos2, questions2  = get_all_convos(STOPWORDS, 'data/trains_hors_sujet.txt')
    convos3, questions3 = get_all_convos(STOPWORDS, 'data/convos3septembre_train.txt')
    convos1.extend(convos2)
    convos1.extend(convos3)
    questions1.extend(questions2)
    questions1.extend(questions3)
    convos_test1, questions_test1 = get_all_convos(STOPWORDS, 'data/tests_16juillet.txt')
    convos_test2, questions_test2 = get_all_convos(STOPWORDS, 'data/convos3septembre_test.txt')
    convos_test1.extend(convos_test2)
    questions_test1.extend(questions_test2)
    index_suff = [i for i in range(len(convos1))]
    random.shuffle(index_suff)
    convos, questions = [], []
    for i in index_suff:
        convos.append(convos1[i])
        questions.append(questions1[i])
    index_suff_ = [i for i in range(len(convos_test1))]
    random.shuffle(index_suff_)
    convos_test, questions_test = [], []
    for i in index_suff_:
        convos_test.append(convos_test1[i])
        questions_test.append(questions_test1[i])    
    return convos, questions, convos_test, questions_test


        

def convos_to_questions(convos):
    """
    prend tous les conversations dans corpus et renvoie un array de documents avec
    des vocabulaires séparés"""
    
    data = []
    for convo in convos:
        data.append(convo[0])
    return data

def get_answer(index):
    if index != None:
        return convos_train[index][1]
    else:
        return 'Désolé, je ne comprends pas ta question'
    
def list_words():
    list_ = []
    for data in DATA:
        for term in split_words(data):
            if term not in list_:
                list_.append(term)
    return list_
        
if __name__ == '__main__':
    
    try:
        convos_train_
    except NameError:
        K = 1/10
        convos_train, questions, convos_test, questions_test = data_processed()
        convos_train.extend(convos_test)
        DATA = convos_to_questions(convos_train)
        start = time.time()
        dictionary =  dict_for_all_doc(DATA)
        KEY_LIST_  = get_key_list(convos_train)
        COMPLET_DICT_TIME = date_time_()
        CITY_LIST = construct_list_city()
        LIST_OF_WORDS = list_words()
        print('Training on {} couples and test on {} couple'\
              .format(len(convos_train), len(convos_test)))
        calcul_precision_recall_(False)
        calcul_precision_recall_(True)
        print('RUNNING TIME IS {:.2f} seconds '.format(time.time()-start))
# Out:
# Training on 2898 couples and test on 597 couple
# ON TEST, WE HAVE: PRECISION = 0.94736,  RECALL = 0.94342, F_MESURE = 0.945
#
# --------------------------------------------------------------------------------
# ON TRAINS, WE HAVE PRECISION = 0.98765,  RECALL = 0.98717, F_MESURE = 0.987
# RUNNING TIME IS 94.77 seconds

# %%
chatting_with_corpus()
# Out:
# Humaine:   voiture immobilisée
# Bot:  #combien# #arrêt#
#
# Humaine:   comment tu t'appelles
# Bot:  je m'appelle Emmet, je suis une création d'AVICEN
#
# Humaine:   je veux voir s'il y a des problèmes
# Bot:  #problème#
#
# Humaine:   il y a problèmes
# Bot:  véhicule #id# #problème# #km#
#
# Humaine:   il y a des urgences
# Bot:  #problème#
#
# Humaine:   problème de freine
# Bot:  #ask_id# #problème# #frein#
#
# Humaine:   problème de vitesse
# Bot:  véhicule #id# #problèmes# #vitesse#
#
# Humaine:   combien de véhicules à l'arrêt?
# Bot:  #étranger#
#
# Humaine:   combien de véhicule en circulation
# Bot:  #total_veh_movement#
#
# Humaine:   il y a des véhicules hors zone définie
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:   il y a des problèmes?
# Bot:  #problème#
#
# Humaine:   coucou
# Bot:  Oui... Euh, non.
#
# Humaine:   trompé
# Bot:  Détendez-vous.
#
# Humaine:   je veux savoir si il y a de problème
# Bot:  #problème#
#
# Humaine:   non, je veux savoir si tout va bien
# Bot:  ça va
#
# Humaine:   nombre de trajets
# Bot:  #ask_id# #combien# #trajet#
#
# Humaine:   combien de km au total
# Bot:  #ask_id# #km#
#
# Humaine:   combien de carburant au total
# Bot:  #ask_id# #consumption#
#
# Humaine:   salut
# Bot:  au revoir
#
# Humaine:   comment tu vas
# Bot:  je m'appelle Emmet, je suis une création d'AVICEN
#
# Humaine:   la flotte
# Bot:  #tco_fleet#
#
# Humaine:   un résume sur flotte
# Bot:  #rapport# #flotte#
#
# Humaine:   qui est président des états-unis
# Bot:  désolé je ne sais pas peut on parler d’autre sujets ou reformuler ta question?
#
# Humaine:   qui est le plus fort
# Bot:  je l'ignore. peut être moi :)
#
# Humaine:   qui est le plus con
# Bot:  je l'ignore. peut être moi :)
#
# Humaine:   qui est plus stupid
# Bot:  C'est pas la boniche ?
#
# Humaine:   a b c d e
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:   qui est le plus fort que tout le monde entier
# Bot:  je l'ignore. peut être moi :)
#
# Humaine:   combien km au total
# Bot:  #ask_id# #km#
#
# Humaine:   combien carburant comsomé
# Bot:  #ask_id# #carburant#
#
# Humaine:   combien carburant
# Bot:  #ask_id# #carburant#
#
# Humaine:   carburant
# Bot:  #ask_id# #carburant#
#
# Humaine:   combien
# Bot:  Ah ! Hé !
#
# Humaine:   je cherche une voiture
# Bot:  #ask_id# #position#
#
# Humaine:   je veux un véhicule le plus vite possible
# Bot:  #vin_proxi#
#
# Humaine:   quel véhicule qui roule moins vite
# Bot:  véhicule #id# #km# #MIN#
#
# Humaine:   la moyenne des vitesse
# Bot:  #moyenne# #vitesse#
#
# Humaine:   vitesse en moyenne
# Bot:  #moyenne# #vitesse#
#
# Humaine:   je cherche un véhicule
# Bot:  #ask_id# #position#
#
# Humaine:   bonjour
# Bot:  bonjour
#
# Humaine:   est ce que tout va bien
# Bot:  ça va
#
# Humaine:   problème
# Bot:  véhicule #id# #problèmes# #vitesse#
#
# Humaine:   combien carburant mon véhicule a comsommé ce mois
# ce mois, #ask_id# #consommation# #moyenne#
#
# Humaine:   la santé des voitures
# Bot:  #ask_id# #problème# #technique#
#
# Humaine:   combien de véhicule sont à l'arrêt?
# Bot:  #combien# #arrêt#
#
# Humaine:   combien de véhicule sont à Lyon
# À Lyon, #combien# #arrêt#
#
# Humaine:   je veux savoir s'il y a des problèmes
# Bot:  #problème#
#
# Humaine:   c'est qui le président de France
# Bot:  désolé je ne sais pas peut on parler d’autre sujets ou reformuler ta question?
#
# Humaine:   c'est quoi
# Bot:  Ça vient d'où ?
#
# Humaine:   combien kilomètrage a parcouru mon véhicule
# Bot:  #ask_id# #km#
#
# Humaine:   combien de km les véhicules sont parcouru en moyenne
# Bot:  #ask_id# #km#
#
# Humaine:   quelle est la distance moyenne
# Bot:  #ask_id# #km#
#
# Humaine:   la vitesse moyenne
# Bot:  véhicule #id# #vitesse# #MOYENNE#
#
# Humaine:   la pression de pneu est bonne
# Bot:  la pression des pneus est #tpms# bar
#
# Humaine:   quels sont les véhicules avec une mauvaise pression de pneu
# Bot:  #ids# #problème# #pression#
#
# Humaine:   quels est le véhicule qui est le moins utilisé
# Bot:  #vin_proxi#
#
# Humaine:   pannes
# Bot:  #panne#
#
# Humaine:   combien de pannes
# Bot:  #panne#
#
# Humaine:   nombre de places
# Bot:  #ask_id# #vin_seat#
#
# Humaine:   nombre de déplacements
# Bot:  #total_veh_movement#
#
# Humaine:   nombre de sieges
# Bot:  il y a #nb_veh#
#
# Humaine:   km
# Bot:  véhicule #id# #erreur# #km#
#
# Humaine:   combien de km
# Bot:  #ask_id# #km#
#
# Humaine:   quel est le nombre de voiture
# Bot:  il y a #nb_veh#
#
# Humaine:   combien de voitures
# Bot:  il y a #nb_veh#
#
# Humaine:   ou est mon contrat
# Bot:  ton véhicule est à #position#
#
# Humaine:   quel est le vin
# Bot:  #ask_id# #vin#
#
# Humaine:   vin
# Bot:  Vu la merde que c'est...
#
# Humaine:   quel véhicule est disponible
# Bot:  vous pouvez vous servir du #list_vin_free#
#
# Humaine:   pression des pneux
# Bot:  la pression des pneus est #tpms# bar
#
# Humaine:   quel est le tpms
# Bot:  #problème#
#
# Humaine:   TPMS
# Bot:  Avec vos fesses.
#
# Humaine:   quelle marque pneu
# Bot:  la marque des pneus est #brand_tyre#
#
# Humaine:   quelle marque voiture
# Bot:  #ask_id# #base_marque#
#
# Humaine:   quelle voiture
# Bot:  véhicule #id# #km# #MIN#
#
# Humaine:   bonsoir
# Bot:  au revoir
#
# Humaine:   combien de véhicule qui roulent
# Bot:  #total_veh_movement#
#
# Humaine:   combien de voitures hors services
# Bot:  #total_véh_mouvement#
#
# Humaine:   je veux une voiture
# Bot:  #ask_id# #position#
#
# Humaine:   veux
# Bot:  Absolument rien.
#
# Humaine:   va
# Bot:  ça va et toi
#
# Humaine:   carburant consommé
# Bot:  #ask_id# #consumption#
#
# Humaine:   combien de voitures qui consommes plus de carburant
# Bot:  #ask_id# #consumption#
#
# Humaine:   je veux savoir la flotte des voitures
# Bot:  la marques des pneus est #brand_tyre#
#
# Humaine:   combien de voitures qui roulent aujourd'hui?
# aujourd'hui, #total_veh_movement#
#
# Humaine:   combien de voitures qui roulent hier?
# hier, #total_veh_movement#
#
# Humaine:   combien véhicules sur la route
# Bot:  #total_veh_movement#
#
# Humaine:   combien véhicule route
# Bot:  #total_veh_movement#
#
# Humaine:   combien véhicule
# Bot:  il y a #nb_veh#
#
# Humaine:   combien de véhicules qui marchent
# Bot:  il y a #nb_veh#
#
# Humaine:   combien de voitures à Lyon
# À Lyon, #étranger#
#
# Humaine:   combien de voiture à Marseille
# À Marseille, #étranger#
#
# Humaine:   combien véhicule en France
# Bot:  il y a #nb_veh#
#
# Humaine:   combien de véhicule en France
# Bot:  il y a #nb_veh#
#
# Humaine:   combien véhicule à Marseille
# À Marseille, #étranger#
#
# Humaine:   combien véhicule circulent aujourd'hui à Lyon
# À Lyon, aujourd'hui, #étranger#
#
# Humaine:   hello
# Bot:  bonjour
#
# Humaine:   il  a des voitures qui roulent actuellement
# actuellement, #total_veh_movement#
#
# Humaine:   combien de véhicule qui roule  à
# Bot:  #étranger#
#
# Humaine:   à Lyon, il  a des problème
# À Lyon, #problème#
#
# Humaine:   il  a des problèmes à Lyon
# À Lyon, #problème#
#
# Humaine:   il y a des voitures qui roulent à
# Bot:  #total_veh_movement#
#
# Humaine:   combien de véhiculent hors de
# Bot:  il y a #nb_veh#
#
# Humaine:   je veux savoir si tout va bien
# Bot:  ça va
#
# Humaine:   combien de voiture qui roulent à
# Bot:  #étranger#
#
# Humaine:   il y a des voitures à Lyon qui roulent
# À Lyon, Merci de contacter au personnel d'AVICEN au #numéro_avicen#
#
# Humaine:   comment ça va
# Bot:  ça va merci
#
# Humaine:   il y a des voitures qui roulent à Paris
# À Paris, #total_veh_movement#
#
# Humaine:   combien de voiture qui roulent à Lyon
# À Lyon, #étranger#
#
# Humaine:   combien de voitures qui roulent  à Lyon
# À Lyon, #étranger#
#
# Humaine:   et à Paris, combien de voitures qui roulent
# À Paris, #étranger#
#
# Humaine:   et à Lyon, combien de voitures qui roulent
# À Lyon, #étranger#
#
# Humaine:   et à Lyon combien
# À Lyon, Je viens.
#
# Humaine:   à Lyon, combien de véhicules qui roulent
# À Lyon, #étranger#
#
# Humaine:   à Marseille, combien de véhicules qui roulent
# À Marseille, #étranger#
#
# Humaine:   je veux savoir si il a des voitures qui roulent à Saint-Etienne
# À Saint-Etienne, #problème#
#
# Humaine:   je veux savoir si il y a des voitures qui roulent à Grenoble
# À Grenoble, #problème#
#
# Humaine:   combien voitures qui roulent
# Bot:  #total_veh_movement#
#
# Humaine:   combien    voitures    qui    roulent
# Bot:  #total_veh_movement#
#
# Humaine:   combien de voiture à paris
# Bot:  #étranger#
#
# Humaine:   combien de voiture qui roulent à paris,
# Bot:  #étranger#
#
# Humaine:   combien de carburant nous avons comsommé ce mois
# ce mois, #ask_id# #consumption#
#
# Humaine:   combien de carburant nous avons comsomé
# Bot:  #ask_id# #consumption#
#
# Humaine:   combien de carburant nous avons comsomé depuis 3 mois
# 3 mois, #ask_id# #consumption#
#
# Humaine:   s'il te plaît
# Bot:  Je veux comprendre.
#
# Humaine:   je veux savoir
# Bot:  #problème#
#
# Humaine:   je veux
# Bot:  je suis là pour t'aider
#
# Humaine:   je suis coincé
# Bot:  contactez-nous lien l'accès au est #brand_tyre#
#
# Humaine:   combien à paris
# Bot:  C'est beaucoup de clodos.
#
# Humaine:   vitesse
# Bot:  véhicule #id# #problèmes# #vitesse#
#
# Humaine:   vitesse maximum
# Bot:  véhicule #id# #vitesse# #MAX#
#
# Humaine:   vitesse minimum
# Bot:  véhicule #id# #vitesse# #MIN#
#
# Humaine:   erreur
# Bot:  véhicule #id# #erreur# #km#
#
# Humaine:   savoir
# Bot:  Je crois.
#
# Humaine:   véhicule
# Bot:  Non.
#
# Humaine:   où est mon véhicule
# Bot:  ton véhicule est à #position#
# Humaine:   comment
# Bot:  Selon Karadoc, un lit doit avoir de quoi vivre 8 jours dedans.
#
# Humaine:   je veux savoir si il y a des voitures à l'étranger
# Bot:  #problème#
#
# Humaine:   combien de
# Bot:  il y a #nb_veh#
#
# Humaine:   faute vitesse
# Bot:  véhicule #id# #erreurs# #vitesse#
#
# Humaine:   au revoir
# Bot:  au revoir
#
# Humaine:   good
# Bot:  Non.
#
# Humaine:   erreur de vitesse
# Bot:  #moyenne# #vitesse#
#
# Humaine:   batterie
# Bot:  véhicule #id# #problème# #batterie#
#
# Humaine:   oui
# Bot:  1 seconde !
#
# Humaine:   des
# Bot:  Ce message confirmait qu'il avait planté l'épée, non ?
#
# Humaine:   pour
# Bot:  C'est pour dormir, pas pour...
#
# Humaine:   combien de km a fait mon véhicule
# Bot:  #ask_id# #km#
#
# Humaine:   fait
# Bot:  Parce que là, peine de mort, pas peine de mort...
#
# Humaine:   faudrais
# Bot:  Évidemment !
#
# Humaine:   localisé
# Bot:  #ask_id# #position#
#
# Humaine:   améliorer
# Bot:  essayer notre module #rde# disponible sur le store
#
# Humaine:   condition
# Bot:  vous pouvez apprécier cela sur la #map_météo#
#
# Humaine:   min
# Bot:  Vous avez rêvé du succès de votre mission ?
#
# Humaine:   je
# Bot:  Merci, Nessa.
#
# Humaine:   je suis
# Bot:  contactez-nous lien l'accès au est #brand_tyre#
#
# Humaine:   coincé
# Bot:  contactez-nous lien l'accès au est #brand_tyre#
#
# Humaine:   frein
# Bot:  #ask_id# #problème# #frein#
#
# Humaine:   pneu
# Bot:  vous trouverez cela ici #spec_tyre#
#
# Humaine:   est-ce qu'on a des problème de pneu
# Bot:  #ask_id# #problème# #frein#
#
# Humaine:   où est
# Bot:  Dépassez l'aspect.
#
# Humaine:   b
# Bot:  C'est pour le feu.
#
# Humaine:   je veux une
# Bot:  je suis là pour t'aider
#
# Humaine:   solution
# Bot:  Pour me renvoyer d'où je viens.
#
# Humaine:   entreprise
# Bot:  Avicen se trouve à 92 cours Lafayette 69003 Lyon
#
# Humaine:   appelles
# Bot:  Un grouillot.
#
# Humaine:   con
# Bot:  pourquoi des mots méchants
#
# Humaine:   qui
# Bot:  Les types qui ont laissé les traces.
#
# Humaine:   question
# Bot:  Oui, mon oncle. Quelques termes de l'énoncé m'échappent.
#
# Humaine:
#
# Humaine:  ures
# Bot:  Je cherche.
#
# Humaine:  de voitures
# Bot:  il y a #nb_veh#
#
# Humaine:  a voiture
# Bot:  Non.
#
# Humaine:  ma voiture
# Bot:  #ask_id# #position#
#
# Humaine:  he ma voiture
# Bot:  #ask_id# #position#
#
# Humaine:  une voiture
# Bot:  #ask_id# #position#
#
# Humaine:  maximale
# Bot:  véhicule #id# #vitesse# #MAX#
#
# Humaine:  ées
# Bot:  Je voulais pas.
#
# Humaine:  is
# Bot:  Si, c'est comme ça.
#
# Humaine:  savoir combien de voiture qui roule à Paris
# À Paris, #étranger#
#
# Humaine:  de valeur tu apporte pour cette boite
# Bot:  #ask_id# #consumption#
#
# Humaine:  voir des infos
# Bot:  je suis là pour t'aider
#
# Humaine:  st cool
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  how are you?
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  mais on parle
# Bot:  Je suis d'accord.
#
# Humaine:  allez les bleus
# Bot:  Vous seriez gonflé.
#
# Humaine:  cool
# Bot:  Non. Du coup, renégats.
#
# Humaine:  t'es con
# Bot:  pourquoi des mots méchants
#
# Humaine:  yes
# Bot:  Si, mais 2 secondes !
#
# Humaine:  bon, je m'arrête là
# Bot:  Au bout d'un moment, ça va bien.
#
# Humaine:  je veux ma voiture
# Bot:  #ask_id# #position#
#
# Humaine:  la batterie est bonne?
# Bot:  véhicule #id# #erreurs# #batterie#
#
# Humaine:  je veux un rapport
# Bot:  #rapport#
#
# Humaine:  combien de trajet mon véhicule a parcouru
# Bot:  #ask_id# #km#
#
# Humaine:  je cherche mon véhicule
# Bot:  #ask_id# #position#
#
# Humaine:  il y a de problèmes de batterie
# Bot:  #problème#
#
# Humaine:  problème de flotte
# Bot:  #ask_id# #problème# #frein#
#
# Humaine:  je veux savoir si nous avons des problèmes de pneus?
# Bot:  #problème#
#
# Humaine:  je veux savoir si nous avons de souci
# Bot:  #problème#
#
# Humaine:  je te remercie beaucoup
# Bot:  de rien
#
# Humaine:  con et con et con
# Bot:  pourquoi des mots méchants
#
# Humaine:  bon, t'es rigolos
# Bot:  Non.
#
# Humaine:  bon, je m'arrête ici
# Bot:  Au bout d'un moment, ça va bien.
#
# Humaine:  à bien tôt
# Bot:  à bien tôt.
#
#
# Humaine:  et avides de tout.
# Bot:  "Tout" quoi ?
#
# Humaine:  Ni moi ni personne.
# Bot:  À part vous, il n'y en a pas eu 50.
#
# Humaine:  Ah ouais ?
# Bot:  On va pouvoir s'arranger.
#
# Humaine:  Il se repose.
# Bot:  Je vais replanter Excalibur.
#
# Humaine:  Allez, vite.
# Bot:  Ça me mouille le pied.
#
# Humaine:  Attention. Ne dévoile pas ton jeu.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  On devrait en acheter une neuve.
# Bot:  Regardez-le bien.
#
# Humaine:  Je connaissais à peine ces garçons.
# Bot:  Oui.
#
# Humaine:  Il a le droit de s'exprimer.
# Bot:  Oui.
#
# Humaine:  Je me demande ce que ça peut être.
# Bot:  Ça va encore discuter.
#
# Humaine:  Il a peur que tu t'en mêles.
# Bot:  je suis là pour tes questions concernants tes voitures
#
# Humaine:  Pêcher notre repas à travers un trou minuscule.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Pas du tout, sahib.
# Bot:  Pour roupiller, vous êtes costaud !
#
# Humaine:  J'ai envie d'un peu de soupe.
# Bot:  Vous le verrez aussi en accélérant.
#
# Humaine:  Je suis Laura.
# Bot:  contactez-nous lien l'accès au est #brand_tyre#
#
# Humaine:  Pardon, je voulais pas déranger.
# Bot:  peux-tu reformuler ta question
#
# Humaine:  Si je gardais le secret, tu me dirais ?
# Bot:  je m'appelles Emmet
#
# Humaine:  Oh, mon Dieu !
# Bot:  Qu'est-ce qu'il y a ?
#
# Humaine:  Je me donne pourtant un mal de chien.
# Bot:  Plus, oui, mais...
#
# Humaine:  Bonne nuit.
# À Bonne, Une. On bosse.
#
# Humaine:  Au secours.
# Bot:  au revoir
#
# Humaine:  Elle vient d'être mise.
# Bot:  Je fais partie du lot.
#
# Humaine:  Comme je suis maintenant.
# maintenant, contactez-nous lien l'accès au est #brand_tyre#
#
# Humaine:  Max voulait 300 mots, mais il y en a 650.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Viens t'asseoir.
# À Viens, Bonne idée.
#
# Humaine:  Monte tout de suite et essaye ton cadeau !
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Hé, petit ! Vite, ça ferme !
# Bot:  En général, ou maintenant ?
#
# Humaine:  Lottie, il ne faut pas s'agiter comme cela.
# Bot:  Il n'y a aucun doute.
#
# Humaine:  Je suis là.
# Bot:  contactez-nous lien l'accès au est #brand_tyre#
#
# Humaine:  Il n'est pas parti.
# Bot:  Hier ? Ça fait combien ?
#
# Humaine:  Elle est vite intimidée.
# Bot:  Oui.
#
# Humaine:  Bien sûr.
# Bot:  Vous aurez beau me dire que je suis pas prêt, que je manque de convictions, ça ne changera rien.
#
# Humaine:  Un petit peu... plus à droite.
# Bot:  Caca.
#
# Humaine:  Bonjour, rats de labo !
# Bot:  Mais comment ça ?
#
# Humaine:  Vous m'avez sauvée du pire.
# Bot:  Quand même, "sauvé"...
#
# Humaine:  Il s'appelle Elliot.
# Bot:  Qu'est-ce que je fais ?
#
# Humaine:  Tu es sûrement en colère.
# Bot:  Il y a erreur.
#
# Humaine:  Je suis Amber.
# Bot:  contactez-nous lien l'accès au est #brand_tyre#
#
# Humaine:  Vous me draguez ?
# Bot:  Pas ce que vous croyez.
#
# Humaine:  "Tu te crèveras un il ? !"
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Je meurs de faim.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Non ! Pas "ra-ra-ra" !
# Bot:  On se réunit pas que pour l'armement.
#
# Humaine:  Amuse-toi bien.
# Bot:  merci
#
#
# Humaine:  Vous venez pas du Minnesota ?
# Bot:  Non ! On vient pas.
#
# Humaine:  Ce n'est pas pareil.
# Bot:  Queue leu leu ou file indienne.
#
# Humaine:  Chérie ?
# Bot:  Non. J'en demande plus cher, mais y a eu le voyage, du coup...
#
# Humaine:  Tu n'as pas de femme à la maison ?
# Bot:  Sans moi.
#
# Humaine:  Vous trois, suivez-moi. Vite.
# Bot:  Oui.
#
# Humaine:  Fichu !
# Bot:  Non. Pas vous.
#
# Humaine:  Je voudrais : une salade niçoise, sauce ranch.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Pourquoi, alors ?
# Bot:  Non, rien.
#
# Humaine:  Tu me l'as déjà dit.
# Bot:  peux-tu préciser ta demande
#
# Humaine:  Vous trois seulement, alors.
# Bot:  Oui.
#
# Humaine:  C'était pas la peine.
# Bot:  Je l'ai jamais connu.
#
# Humaine:  Je ne veux pas laisser mon père.
# Bot:  Tout juste.
#
# Humaine:  "et un amour plus fort que les liens du sang."
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Le quorum est sûrement atteint.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Délicieux.
# Bot:  Je me souviens plus.
#
# Humaine:  T'es un gentil garçon.
# Bot:  merci
#
#
# Humaine:  Vous êtes sûr ?
# Bot:  Le prenez pas mal.
#
# Humaine:  sont juchés les esprits...
# Bot:  Qu'en faites-vous, de l'esprit ?
#
# Humaine:  Je ne laisserai pas gagner sans me battre.
# Bot:  Vous n'avez pas le droit.
#
# Humaine:  Ce n'est pas du premier choix.
# Bot:  Le père ou l'oncle ?
#
# Humaine:  Je crois avoir vu quelque chose. . .
# Bot:  Avez-vous à manger à portée de main ?
#
# Humaine:  J'ai pas braillé !
# Bot:  Que voulez-vous ? Ils doivent voir le roi.
#
# Humaine:  Elle est fantastique.
# Bot:  Oui.
#
# Humaine:  Je t'aime.
# Bot:  C'est qui, ceux-là ?
#
# Humaine:  Par chance, j'avais l'avantage de l'expérience.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Partons.
# Bot:  Nom de nom de nom, que voulez-vous ?
#
# Humaine:  Je viens examiner les vignes.
# Bot:  génial découvrez notre module RDE ou Real Driving Emissions
#
# Humaine:  Il faut que tu la baises.
# Bot:  Il est trop pourri, le discours !
#
# Humaine:  C'est Charlie.
# Bot:  Là.
#
# Humaine:  Elle plaît à Simon.
# Bot:  Je veux comprendre.
#
# Humaine:  A cache-cache.
# Bot:  Le truc, c'est que je ne crois pas que j'aie un fils caché.
#
# Humaine:  Non, mais il n'a pas besoin de le savoir.
# Bot:  C'est la reine Guenièvre qui m'envoie.
#
# Humaine:  Moi non plus. Suivez-moi.
# Bot:  Vous avez renoncé à la femme du seigneur Karadoc.
#
# Humaine:  Je ne serai jamais à l'heure à ma réunion.
# Bot:  J'aime mieux me taire.
#
# Humaine:  Douze heures. Peut-être dix.
# À Douze, la durée du trajet est approximativement de #calcul_roadtrip#
#
# Humaine:  Convaincu que la mort,
# Bot:  Non. Je ne suis convaincu de rien du tout.
#
# Humaine:  J'étais en présence de la plus belle machine
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Un soda ?
# Bot:  Pas comme un père !
#
# Humaine:  Tiens.
# Bot:  #ask_id# #position#
#
# Humaine:  Il y a un mois.
# un mois, Non.
#
# Humaine:  Ovaltine ?
# Bot:  Possible, et alors ?
#
# Humaine:  C'est ta ferme, ici ?
# Bot:  À ceux qui me doivent.
#
# Humaine:  Bizarre. Sous l'emprise de l'alcool, il aurait pu parler de... sa progéniture.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Non.
# Bot:  Non.
#
# Humaine:  Je disais au capit. . .
# Bot:  Ouais !
#
# Humaine:  On ne pouvait pas rentrer hier soir.
# hier, Non, hors de question.
#
# Humaine:  Écoutez ça.
# Bot:  Il toque.
#
# Humaine:  Il paraît que c'était un grand homme.
# Bot:  Je fais mon boulot...
#
# Humaine:  Ça, c'est très peu probable.
# Bot:  Non, le bras droit.
#
# Humaine:  Il n'y a qu'une solution : faire un énorme festin avant d'aller dormir.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Papa t'achètera...
# Bot:  Non. J'en demande plus cher, mais y a eu le voyage, du coup...
#
# Humaine:  On est à court.
# Bot:  À Arthur.
#
# Humaine:  Et si l'oiseau ne veut pas...
# Bot:  Tout juste.
#
# Humaine:  Ce vin n'est pas trop mauvais.
# Bot:  Non. Entrez !
#
# Humaine:  Du vin ?
# Bot:  Vu la merde que c'est...
#
# Humaine:  Parle-moi de ton copain Charlie.
# Bot:  de rien
#
# Humaine:  Mon 1er pilotage.
# Bot:  Non.
#
# Humaine:  Vous vendez La Siroque ?
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  C'est un bovin.
# Bot:  Non.
#
# Humaine:  Si l'un de nous deux saute, ce devrait être moi.
# Bot:  Qu'y a-t-il, sire ?
#
# Humaine:  Une femme intelligente et belle comme toi a sûrement beaucoup de succès.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Si j'avais gardé ma tête de benêt
# Bot:  Un gros pain dans votre tête.
#
# Humaine:  Richard.
# Bot:  Vous êtes pressé ?
#
# Humaine:  N'oublie pas d'appeler.
# Bot:  "Kijou" ?
#
# Humaine:  De moi.
# Bot:  Je suis d'accord.
#
# Humaine:  Vous ne me croyez pas.
# Bot:  Convoiter la femme d'un chevalier est extrêmement grave.
#
# Humaine:  Ça n'a aucun intérêt.
# Bot:  La surprise, seigneur Dagonet.
#
# Humaine:  C'était Arthur.
# Bot:  L'unijambiste.
#
# Humaine:  Une carriole arrive sur la route nord.
# Bot:  il y #total_veh_movement# véhicules en circulation
#
# Humaine:  Il m'a trahi.
# Bot:  Non.
#
# Humaine:  Tu rougis.
# Bot:  je suis là pour tes questions concernants tes voitures
#
# Humaine:  J'ai... bien entendu ?
# Bot:  Quoi encore ?
#
# Humaine:  Ou c'était la chèvre ?
# Bot:  Non, je crois que ça venait des arbres.
#
# Humaine:  D'où cela sort ?
# Bot:  Vous saviez pas par où.
#
# Humaine:  Cette Martha Anderson n'est pas nette et je vais découvrir son secret.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  J'en sais rien.
# Bot:  Vous vivez avec ?
#
# Humaine:  On n'attend plus que vous !
# Bot:  Je croyais que vous aviez fini.
#
# Humaine:  Lancelot du Lac ?
# Bot:  Oui, lui-même.
#
# Humaine:  Kerouac, par exemple, tu le trouves facilement.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Chez les jurisconsultes, ça a fait un bruit !
# Bot:  Le bruit, la mer, les bateaux, j'en ai jusque-là.
#
# Humaine:  Non, je crois que ça venait des arbres.
# Bot:  Vous avez un talent fou !
#
# Humaine:  Vous n'en trouverez pas de meilleur que celui-là.
# Bot:  C'était : sur la branche.
#
# Humaine:  Encore tes combines...
# Bot:  Il n'y a personne.
#
# Humaine:  Et puis, on a commencé à se voir.
# Bot:  J'en sais rien !
#
# Humaine:  Gengis Khan n'est pas mort.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  C'est important.
# Bot:  Non. Une clé qui correspond à la serrure.
#
# Humaine:  En sécurité.
# Bot:  Sur ça, on a toujours eu du retard.
#
# Humaine:  Nous n'avons pas de moyens illimités.
# Bot:  il y a #nb_véhicule#
#
# Humaine:  Vous êtes là ?
# Bot:  Hein ?
#
# Humaine:  On pense tous que vous êtes un con.
# Bot:  J'en sais rien. Je suis écuré.
#
# Humaine:  Vite, vite, toujours vite !
# Bot:  au revoir
#
# Humaine:  Bonsoir... inspecteur-chef Hill, et Inspecteur Mackenzie.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  En Ecosse.
# Bot:  En toute technique d'arrosage.
#
# Humaine:  Pas mal.
# Bot:  Je vous en pose, des questions ?
#
# Humaine:  Tout le monde s'en fout.
# Bot:  Ben oui.
#
# Humaine:  On n'en est plus là, hein ?
# Bot:  Possible, et alors ?
#
# Humaine:  C'est un petit peu le corollaire.
# Bot:  Caca.
#
# Humaine:  Vous avez jamais profité d'une prisonnière peut-être ?
# Bot:  Non, figurez-vous.
#
# Humaine:  Aux enfants.
# Bot:  Oui, je crois que je les déstabilise.
#
# Humaine:  L'un a 13 ans, l'autre a 11 mois.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  On s'en fout.
# Bot:  Je pars avec vous.
#
# Humaine:  Où est la piqûre ?
# Bot:  Au pied. Il a doublé de volume.
#
# Humaine:  T'as dit un truc, et au réveil, t'avais oublié.
# Bot:  C'est quoi, ça ?
#
# Humaine:  Ça nous renvoie à notre utilité.
# Bot:  Nous ! C'est moi !
#
# Humaine:  Oh ! Ça va !
# Bot:  ça va et toi
#
# Humaine:  Non. Laissez-le brûler.
# Bot:  Non.
#
# Humaine:  Sur la Table ronde ?
# À Table, il y #total_veh_movement# véhicules en circulation
#
# Humaine:  Je sais ni boire, ni manger, ni m'habiller, ni me laver, ni rien.
# Bot:  Ils m'ont...
#
# Humaine:  C'est votre allié.
# Bot:  Y en a tellement...
#
# Humaine:  Pour nous épier ?
# Bot:  oui, #ask_id# #position#
#
# Humaine:  Ben, ça change le visage.
# Bot:  Seul le possesseur sera désigné roi.
#
# Humaine:  D'autant qu'ils ne parlent pas la langue.
# Bot:  Allez, un mercenaire.
#
# Humaine:  Où va le fric, à Kaamelot ?
# Bot:  Faut pas exagérer.
#
# Humaine:  Il est du côté de que dalle : il pige rien.
# Bot:  Il est du côté de que dalle : il pige rien.
#
# Humaine:  En somme.
# Bot:  En toute technique d'arrosage.
#
# Humaine:  "OK", quoi ? L'héritier ?
# Bot:  Non. L'épée.
#
# Humaine:  Non, sire.
# Bot:  Je reprends : vous vous plaignez de quoi ?
#
# Humaine:  "Là", où ?
# Bot:  Vous saviez pas par où.
#
# Humaine:  D'accord, on annule.
# Bot:  Inversez tout, et vous vous y retrouverez.
#
# Humaine:  Il est là.
# Bot:  Les chambres au 1er.
#
# Humaine:  Voilà.
# Bot:  Le Seigneur Bohort.
#
# Humaine:  Quoi ? Je pige pas ou quoi ?
# Bot:  Et il est charmant.
#
# Humaine:  Chut !
# Bot:  N'influencez pas !
#
# Humaine:  Elle serait vêtue de blanc.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Exactement.
# Bot:  oui, #ask_id# #position#
#
# Humaine:  Perceval, dites une phrase au hasard.
# Bot:  Arthur, il est de Kaamelott !
#
# Humaine:  J'apprécie les fruits au sirop.
# Bot:  On fout pas le camp avec un chevalier.
#
# Humaine:  Pourquoi laissez-vous vos chevaliers former des clans séparatistes, alors que l'une de vos priorités a toujours été de fédérer les clans autour de votre royaume et de la quête du Graal ?
# Bot:  Euh...
# Humaine:  Le roi d'Orcanie vous a élevé, mais vous êtes un fils de pécore.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  C'était une autre époque.
# Bot:  L'unijambiste.
#
# Humaine:  Ils sont pas affinés.
# Bot:  Y a qu'à leur demander.
#
# Humaine:  On me l'a déjà faite.
# Bot:  Je ne me suis pas levée.
#
# Humaine:  Du calme.
# Bot:  Vous savez bien.
#
# Humaine:  Elle m'a fendu le tibia avec une amphore.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Pourquoi s'emmerder avec ça ?
# Bot:  D'accord, mais Excalibur, il la replante pas tous les matins.
#
# Humaine:  La couronne ne dispense pas de se bien conduire.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Soyez gentille, lâchez-moi la chemise.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Il se peut que des connards se mettent à crier au traître.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Obligé.
# Bot:  #oui/non#
#
# Humaine:  Vous voyez ça ?
# Bot:  Ils viendront de partout.
#
# Humaine:  Ouais !
# Bot:  On va pouvoir s'arranger.
#
# Humaine:  À vous d'avoir de l'attention.
# Bot:  Tout le monde s'y retrouve.
#
# Humaine:  Pourquoi ne pas inviter un chevalier qui l'a présidée ?
# Bot:  Mais c'est Arthur !
#
# Humaine:  J'aime trop les poissons.
# Bot:  Ils peuvent mal le prendre.
#
# Humaine:  Si je suis si douée, pourquoi les clients veulent que je les rembourse ?
# Bot:  C'est moi qui t'inspire, peut-être.
#
# Humaine:  Ah...
# Bot:  Je fais court.
#
# Humaine:  Ils peuvent mal le prendre.
# Bot:  #problème#
#
# Humaine:  Ah non, mais !
# Bot:  Non.
#
# Humaine:  Comment saurais-je ?
# Bot:  Vous devez bien savoir comment on fait.
#
# Humaine:  Vous qui n'en avez pas, vous ne savez pas à quoi vous échappez.
# Bot:  Si. M'en coller plein les fouilles, donc il me faut un bon gros bourgeois.
#
# Humaine:  Éventuellement de...
# Bot:  Ce message confirmait qu'il avait planté l'épée, non ?
#
# Humaine:  Si vous ne venez pas tout de suite, je vous attaque !
# Bot:  Tout juste.
#
# Humaine:  Je m'en fous, des honneurs.
# Bot:  Il dort.
#
# Humaine:  J'y suis pour rien.
# Bot:  Le bruit court que...
#
# Humaine:  Je montre un peu les dents, mais il vous fallait une mise au point.
# Bot:  Ben... J'en ai pas grand-chose à carrer.
#
# Humaine:  Qu'en savez-vous ?
# Bot:  J'ai vu l'acte d'annulation.
#
# Humaine:  Pas mal. C'est rythmique.
# Bot:  Je vous en pose, des questions ?
#
# Humaine:  Ah non ! Quand même...
# Bot:  Non.
#
# Humaine:  Pardon de déranger, nous aimerions voir le roi.
# Bot:  peux-tu reformuler ta question
#
# Humaine:  Mais elle est super.
# Bot:  Oui.
#
# Humaine:  Rien. Peau de zob.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Si elle me demandait d'attaquer vos armées, je le ferais sans réfléchir.
# Bot:  Vous m'avez dit de me retirer.
#
# Humaine:  C'est Yvain, son fils.
# Bot:  Ou sa fille.
#
# Humaine:  Allez.
# Bot:  Ça me mouille le pied.
#
# Humaine:  Faites tout.
# Bot:  Les jolies.
#
# Humaine:  Alors, c'est ici que ça se passe ?
# Bot:  Seigneur Lancelot.
#
# Humaine:  Taillons le bout de gras avec les traîtres.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Les choses avancent petit à petit.
# Bot:  En général, ou maintenant ?
#
# Humaine:  C'est peut-être un mec normal.
# Bot:  Je sais pas.
#
# Humaine:  La reine Guenièvre.
# Bot:  Ah !
#
# Humaine:  Le mieux, c'est une clé.
# Bot:  On vient vous rappeler la réunion de ce matin.
#
# Humaine:  Il va aux fermes.
# Bot:  S'évanouir.
#
# Humaine:  Le seigneur Lancelot a dit pas avec les gens de Kaamelott !
# Bot:  Voilà. Elle sort la tête de l'eau.
#
# Humaine:  Euh... oui, une fille.
# Bot:  En somme.
#
# Humaine:  On fait courir le bruit qu'on est des voyageurs bourrés de blé.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Ça va. Foutez le camp.
# Bot:  Où, chez moi ?
#
# Humaine:  C'est impossible.
# Bot:  Là.
#
# Humaine:  "Pute", "chier".
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Je balance le mot de passe, et je reviens.
# Bot:  Oui.
#
# Humaine:  Et si je la retirais, ça arrangerait le coup ?
# Bot:  Ici... c'est pas pour l'éternité.
#
# Humaine:  Ce sera bien.
# Bot:  En fait, un peu avec toutes.
#
# Humaine:  Donc, ça change pas d'avant ?
# Bot:  Non, ne soyez pas déstabilisé.
#
# Humaine:  Attendez.
# Bot:  À 5 h ? Non.
#
# Humaine:  Même en partie ?
# Bot:  Non. Si c'est Loth, je serai plus pas jouasse que surpris.
#
# Humaine:  1 seconde !
# Bot:  Y en a un, je sais même pas comment il s'appelle. Un barbu...
#
# Humaine:  Que faites-vous là ?
# Bot:  Votre bras ?
#
# Humaine:  Pioncer autant, c'est pas le genre de la maison.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Vous n'allez pas la replanter.
# Bot:  Vous n'avez pas le droit.
#
# Humaine:  Vous devez bien savoir comment on fait.
# Bot:  C'est reparti.
#
# Humaine:  Il vous a montré la voie.
# Bot:  Mais c'est mon épouse.
#
# Humaine:  On n'a pas besoin de Tintagel.
# Bot:  C'est la reine Guenièvre qui m'envoie.
#
# Humaine:  Vous vous entraînerez !
# Bot:  M'insulter, ça vous revigore.
#
# Humaine:  Le lit en lui-même...
# Bot:  Vous êtes pas un peu chochotte ?
#
# Humaine:  Depuis que Karadoc a créé son clan autonome, je ne peux plus venir.
# Bot:  On n'y habite plus ?
#
# Humaine:  Magnez-vous !
# Bot:  Taisez-vous !
#
# Humaine:  Mais je ne suis pas responsable de ça.
# Bot:  Oui, père.
#
# Humaine:  Non. Tu as quelque chose.
# Bot:  De quoi ?
#
# Humaine:  Excusez-nous, Sire.
# Bot:  Je reprends : vous vous plaignez de quoi ?
#
# Humaine:  Le roi Loth est là avec Galessin, Dagonet et Gauvain.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Comme Excalibur, qui montre c'est qui qui commande ?
# Bot:  C'est rien. Qui vous emmerde ?
#
# Humaine:  Tu veux savoir quoi ?
# Bot:  On arrête ?
#
# Humaine:  C'est sain.
# Bot:  Là.
#
# Humaine:  Vous vous foutez de nous ?
# Bot:  Qu'y a-t-il, sire ?
#
# Humaine:  Les dieux m'ont b...
# Bot:  Mais non ! Allons...
#
# Humaine:  Retournez à vos petites affaires.
# Bot:  Le souci, c'est qu'il est sensible, fragile...
#
# Humaine:  C'est magique.
# Bot:  Là.
#
# Humaine:  Formation de la tortue et pas là.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  "virtuellement".
# Bot:  J'en étais trop sûr que ça allait faire des histoires.
#
# Humaine:  C'est long comme ça ?
# Bot:  Vous en avez déjà vu ?
#
# Humaine:  Parce que pour moi, ça compte, la bouffe.
# À Parce, Non.
#
# Humaine:  J'en ai marre.
# Bot:  Oh, ben...
#
# Humaine:  Je sais pas. J'écoutais pas.
# Bot:  Pour nous, en Orcanie, le roi Arthur est un joyeux glandu.
#
# Humaine:  Ne criez pas dans mon théâtre.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Genre :
# Bot:  Genre :
#
# Humaine:  2 h du matin, pas avant.
# Bot:  Non, ne soyez pas déstabilisé.
#
# Humaine:  Oui. Parfaitement.
# Bot:  1 seconde !
#
# Humaine:  Et pour un roi qui va vous cogner ?
# Bot:  Vous prenez ça trop à coeur.
#
# Humaine:  "Replanter l'épée"...
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Les malles sont vides, il reste des sous-vêtements.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  La tête, c'est aussi important que le reste.
# Bot:  Posez votre question pourrie et foutez la paix à mon parchemin.
#
# Humaine:  Ça a dû vous secouer.
# Bot:  C'était le mieux à faire.
#
# Humaine:  On en est encore là ?
# Bot:  Je pensais que vous aviez oublié.
#
# Humaine:  C'est possible... c'est possible que j'aie une fille.
# Bot:  Vous avez un talent fou !
#
# Humaine:  Vous voulez rationaliser le débat, même si je pense qu'on ne peut pas le réduire à ça.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  C'est qui, lui ?
# Bot:  C'est rien. Qui vous emmerde ?
#
# Humaine:  Il y en a peut-être qui nettoient.
# Bot:  Oui. Ça se sait, ça.
#
# Humaine:  Où allons-nous vivre ?
# Bot:  On est censés vous céder un bout de terre.
#
# Humaine:  Et Kaamelott ?
# Bot:  C'est fini.
#
# Humaine:  On vous retrouve.
# Bot:  Pas en réunion.
#
# Humaine:  Nous dormons dans nos lits.
# Bot:  C'est absurde.
#
# Humaine:  Je ne suis pas forcément super pressé.
# Bot:  le véhicule le plus proche est #vin_proxi#
#
# Humaine:  Une pelagière ?
# Bot:  Oui, pour aider en cuisine.
#
# Humaine:  Tu es...
# Bot:  Entre.
#
# Humaine:  Elle est partie. Ça nous fait mal.
# Bot:  Nous ! C'est moi !
#
# Humaine:  Les types qui ont laissé les traces.
# Bot:  #ask_id# #conduite#
#
# Humaine:  Je suis censé dormir à Kaamelott, car je vois le roi à l'aube.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Et on a fait des choses.
# Bot:  Avant hier.
#
# Humaine:  Ah ? Vraiment, la chose militaire me restera mystérieuse jusqu'au bout.
# Bot:  Vous n'aviez qu'à faire vos classes.
#
# Humaine:  Au fait, toutes mes condoléances.
# Bot:  Les jolies.
#
# Humaine:  Sire, n'écoutez pas trop ce qu'on dit. On est cons, nous.
# Bot:  Non. Entrez !
#
# Humaine:  Je les ai vendues.
# Bot:  Avec joie.
#
# Humaine:  Non, pas deux.
# Bot:  On se réunit pas que pour l'armement.
#
# Humaine:  9 500 pièces d'or.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Mais on peut rien dire !
# Bot:  En plus, on n'est pas là pour ça.
#
# Humaine:  Défilez, les petites fourmis.
# Bot:  Si vous m'embarquez dans une histoire à 2 ronds 50, je vais vous botter le cul.
#
# Humaine:  Vous venez, ou vous venez pas ?!
# Bot:  Non ! On vient pas.
#
# Humaine:  Si votre plumard brûle, vous y retournez plus vite ?
# Bot:  J'en étais trop sûr que ça allait faire des histoires.
#
# Humaine:  3 bains par semaine.
# Bot:  Lesquelles ?
#
# Humaine:  Justement, je vous l'ai marqué là pour que vous ayez une idée du préjudice.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Pour retirer
# Bot:  Vous auriez dû être le premier.
#
# Humaine:  Mais il faut chercher quand même.
# Bot:  Tout ce que vous voulez, mais sans plus d'indications...
#
# Humaine:  Qu'est-ce que vous voulez ?
# Bot:  Tout. J'adore la lecture.
#
# Humaine:  Vous prévenez trop tard.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Évidemment. Ne l'écoutez pas.
# Bot:  Il toque.
#
# Humaine:  Bon. C'est prêt quand ?
# Bot:  Il faut que j'y retourne.
#
# Humaine:  C'en est pas un ?
# Bot:  Je ne sais pas.
#
# Humaine:  Non ?
# Bot:  Non.
#
# Humaine:  Fini de glander !
# Bot:  Je suis de trop.
#
# Humaine:  A-t-on déjà été tous d'accord ?
# Bot:  Inversez tout, et vous vous y retrouverez.
#
# Humaine:  Plus rien ne tient debout.
# Bot:  C'est quoi, ces fringues ?
#
# Humaine:  Alors là, pareil : c'est banal, mais ne jamais négliger les bienfaits du couple, surtout quand on est a un poste de décision. J'ai toujours mené mes troupes de façon laborieuse.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Et si l'absence de réponses était due à l'absence de Caius ?
# Bot:  Ça se tient, oui.
#
# Humaine:  On passe pour quoi ?
# Bot:  Pourquoi je passe devant Caius ?
#
# Humaine:  J'ai juste le droit de la fermer ?
# Bot:  Oui.
#
# Humaine:  J'ai une traumatite.
# Bot:  oui pose ta question
#
# Humaine:  C'est votre style, d'être cul nu ?
# Bot:  On nous a dit que vous passeriez vers midi. On a été pris de court.
#
# Humaine:  Les yeux qui brillent et tout.
# Bot:  Vous, vous avez un machin qui dit que vous êtes chefs ?
#
# Humaine:  On serait exposés.
# Bot:  Un par jour, ça va pas nous aider.
#
# Humaine:  C'est une ancienne maîtresse.
# Bot:  Je vais voir.
#
# Humaine:  Je sais pas.
# Bot:  Pour nous, en Orcanie, le roi Arthur est un joyeux glandu.
#
# Humaine:  Je n'en aurai jamais.
# Bot:  Il dort.
#
# Humaine:  Car j'ai certaines choses à vous dire.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  La reine ne fout rien.
# Bot:  Quand j'ai regardé les armoires, hier, j'ai cru à un cambriolage.
#
# Humaine:  Je dois raconter mon aventure.
# Bot:  L'auberge était complète
#
# Humaine:  Il était beurré.
# Bot:  Comment ça, "comment" ?
#
# Humaine:  On fait trop paysans pour vous, duchesse ?
# Bot:  Ouais ? Un petit commentaire ?
#
# Humaine:  Y a pas de quoi rougir.
# Bot:  Non.
#
# Humaine:  C'est mon laboratoire et j'estime...
# Bot:  ton véhicule est à #position#
#
# Humaine:  Sa vie est moins inepte ?
# Bot:  Ça m'échappe.
#
# Humaine:  Il y en a, des noms, mais rétro-planifié, je vois pas.
# Bot:  Vous battez pas.
#
# Humaine:  Vous le voulez pas comme 2e ?
# Bot:  Vous préférez en avoir un autre ?
#
# Humaine:  Ils rient.
# Bot:  Le roi Loth a loupé son essai.
#
# Humaine:  C'est un défavorisé dont le regard m'a aidé à dénouer un conflit personnel.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  Je ne saurais pas dire.
# Bot:  Soupir.
#
# Humaine:  Mevanwi soupire.
# Bot:  Hmm ?
#
# Humaine:  Pas très bien, non.
# Bot:  pourquoi des mots méchants
#
# Humaine:  "De quoi ?"
# Bot:  J'adore les voyageurs, les itinérants.
#
# Humaine:  "À la taverne" ?
# Bot:  Ça se couple avec un autre projet.
#
# Humaine:  Le peuple m'en veut...
# Bot:  Quand on gouverne, on donne des signes forts.
#
# Humaine:  "Pédale", plutôt ?
# Bot:  En tout cas, pas méchamment.
#
# Humaine:  Je tape pas pour mon plaisir.
# Bot:  Si, mais je pars quand je veux.
#
# Humaine:  Simplement, je me demandais...
# Bot:  Vous, sentimentalement, vous savez vous assumer.
#
# Humaine:  Bravo.
# Bot:  #ask_id# #conduite#
#
# Humaine:  Mais non !
# Bot:  Vous avez renoncé à la femme du seigneur Karadoc.
#
# Humaine:  Occupons-nous un poste de prestige ?
# Bot:  Ah ?
#
# Humaine:  "Tôt" ? Il ne fait même pas jour.
# Bot:  Pourquoi vous êtes réveillé ?
#
# Humaine:  Comment vous appeler...
# Bot:  Sous-titrage : Télétota
#
# Humaine:  Un barbu ? Quel barbu ?
# Bot:  Oh... Hein ! Vous voyez ?
#
# Humaine:  L'amour.
# Bot:  Qu'est-ce que ça change ?
#
# Humaine:  Je ne sais pas. Tôt.
# Bot:  Pour nous, en Orcanie, le roi Arthur est un joyeux glandu.
#
# Humaine:  "J'entends quelqu'un approcher."
# Bot:  Hé.
#
# Humaine:  Qu'est-ce que ça veut dire ?
# Bot:  Mission accomplie.
#
# Humaine:  J'en aurai des blondes.
# Bot:  C'était le mieux à faire.
#
# Humaine:  "Seigneur Galessin", comme avant. C'est respectueux.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  On a du boulot.
# Bot:  Pour roupiller, vous êtes costaud !
#
# Humaine:  Comment ça ?
# Bot:  Elle tire pas.
#
# Humaine:  Je ne sais pas.
# Bot:  Pour nous, en Orcanie, le roi Arthur est un joyeux glandu.
#
# Humaine:  t'es rigolo
# Bot:  merci
#
#
# Humaine:  je cherche ma voiture
# Bot:  #ask_id# #position#
#
# Humaine:  quelle voiture plus rapide
# Bot:  véhicule #id# #km# #MIN#
#
# Humaine:  quelle voiture vitesse plus rapide
# Bot:  véhicule #id# #vitesse# #MIN#
#
# Humaine:  quelle est la voiture vitesse plus rapide
# Bot:  véhicule #id# #vitesse# #MIN#
#
# Humaine:  Mon père.
# Bot:  Pas comme un père !
#
# Humaine:  C'est sûrement la chose à faire.
# Bot:  Il y a erreur.
#
# Humaine:  Ah oui ?
# Bot:  C'est tout moisi, seigneur breton.
#
# Humaine:  Travailler ensemble ?
# Bot:  Travailler ensemble ?
#
# Humaine:  J'ai pas le droit d'essayer ?
# Bot:  Oui.
#
# Humaine:  Non, mais ils y sont pour rien.
# Bot:  Le bruit court que...
#
# Humaine:  Ça va, vous avez compris.
# Bot:  ça va et toi
#
# Humaine:  Là.
# Bot:  Je laisse tout.
#
# Humaine:  Le boulgour.
# Bot:  Vous avez un camp ?
#
# Humaine:  C'était du lait chaud.
# Désolé, je ne comprends pas ta question, peux tu la reformuler s'il te plaît?
#
# Humaine:  C'est midi passé.
# Bot:  Non.
#
# Humaine:  Dans quelques jours.
# Bot:  De quoi ?
#
# Humaine:  Il est près de son père.
# Bot:  Il est du côté de que dalle : il pige rien.
#
# Humaine:  Cette épée-là.
# Bot:  L'amour.
#
# Humaine:  Oui. Excusez-moi.
# Bot:  1 seconde !
#
# Humaine:  Ça peut faire sourire.
# Bot:  Ça va encore discuter.
#
# Humaine:  Oui, père.
# Bot:  1 seconde !
#
# Humaine:  très bien
# Bot:  au revoir
#
# Humaine:  je ne fais rien
# Bot:  Il ne faut quand même pas avoir les genoux branlants.
#
# Humaine:  je veux ma femme
# Bot:  Oh ! Ça va !
#
# Humaine:  qui es tu
# Bot:  Les types qui ont laissé les traces.
#
# Humaine:  où est la voiture
# Bot:  ton véhicule est à #position#
#
# Humaine:  tu dis de con
# Bot:  Toutes sortes.
#
# Humaine:  oh, je ne comprends pas
# Bot:  Qu'est-ce qu'il y a ?
#
# Humaine:  il y a de problème de pneu
# Bot:  #problème#
#
# Humaine:  bon, on parle d'autre chose
# Bot:  Non.
#
# Humaine:  on parle de lui alors
# Bot:  Je suis d'accord.
#
# Humaine:  non, pas toi, lui
# Bot:  Il dort.
#
# Humaine:  je cherche mes voitures
# Bot:  #ask_id# #position#
#
# Humaine:  c'est pas évident de comprendre ce que tu dis
# Bot:  "C'est des oiseaux qui ne volent pas
#
# Humaine:  c'est quoi ton prénom
# Bot:  Je m'appelles Emmet
#
# Humaine:  tu travaille pour avice
# Bot:  Pour personne. Pour bibi !
#
# Humaine:  sois poli
# Bot:  Non, mais c'est drôle.
#
# Humaine:  c'est quoi ta date de naissance
# Bot:  #ask_id# révision#
#
# Humaine:  tu as quel âge
# Bot:  4 ans.
#
# Humaine:  ça va
# Bot:  ça va et toi
#
# Humaine:  combien de véhicules nous avons
# Bot:  il y a #nb_veh#
#
# Humaine:  quel véhicule de vitesse minimale
# Bot:  véhicule #id# #vitesse# #MIN#
#
# Humaine:  quelle voiture de baisse baterie
# Bot:  véhicule #id# #km# #MIN#
#
# Humaine:  quelle voiture qui a le problème de batterie
# Bot:  véhicule #id# #problèmes# #batterie#
#
# Humaine:  il y a des véhicules à Lyon
# À Lyon, #étranger#
#
# Humaine:  combien de véhicules dans notre parc
# Bot:  il y a #nb_véhicule#
#
# Humaine:  quelle est ton rôle dans l'entreprise?
# Bot:  avicen se trouve à 92 cours lafayette 69003 lyon
#
# Humaine:  quel âge tu as
# Bot:  4 ans.
#
# Humaine:  tu parle anglais?
# Bot:  Allez-y.
#
# Humaine:  combien de véhicules en arrêt
# Bot:  #combien# #arrêt#
#
# Humaine:  où est mon copain
# Bot:  ton véhicule est à #position#
#
# Humaine:  quoi de neuf
# Bot:  Vous m'êtes familier et troublant à la fois.
#
# Humaine:  femme
# Bot:  Ils sont pas affinés.
#
# Humaine:  roi
# Bot:  Il est chez lui, alors il va pas se gêner pour visiter un camp qu'il a payé.
#
# Humaine:  combien voitures au parc
# Bot:  il y a #nb_véhicule#
#
# Humaine:  es tu une fille?
# Bot:  En somme.
#
# Humaine:  comment ton prénom
# Bot:  je m'appelle Emmet, je suis une création d'AVICEN
#
# Humaine:  c'est quoi avicen
# Bot:  Ça vient d'où ?
#
# Humaine:  bye
# Bot:  au revoir
#
# Humaine:  donc
# Bot:  Donc quoi ?
#
# Humaine:  fille
# Bot:  Madenn.
#
# Humaine:  merci
# Bot:  de rien
#
# Humaine:  la position
# Bot:  #problème#
#
# Humaine:  position
# Bot:  #problème#
#
# Humaine:  qui est vous
# Bot:  C'est pas la boniche ?
#
# Humaine:  enfant
# Bot:  Combien d'enfants ? Deux.
#
# Humaine:  gars
# Bot:  J'en sais rien.
#
# Humaine:  surprise
# Bot:  Guenièvre est revenue.
#
# Humaine:  quelle voiture qui est moins vite
# Bot:  véhicule #id# #km# #MIN#
#
# Humaine:  mais non
# Bot:  Vous avez renoncé à la femme du seigneur Karadoc.
#
# Humaine:  quand
# Bot:  Demain.
#
# Humaine:  quoi
# Bot:  Exactement.
#
# Humaine:  bon, je veux ma voiture
# Bot:  #ask_id# #position#
#
# Humaine:  où sont les enfants
# Bot:  l'ensemble des modules disponibles sont sur le store
#
# Humaine:  à tout à l'heure
# Bot:  Si. C'est un animal.
#
# Humaine:  je veux un renseignement
# Bot:  je suis là pour t'aider
#
# Humaine:  et le roi est où
# Bot:  Cette épée-là.
#
# Humaine:  on mange quand
# Bot:  Mangez.
#
# Humaine:  je mange
# Bot:  Mangez.
#
# Humaine:  où sont les filles
# Bot:  l'ensemble des modules disponibles sont sur le store
