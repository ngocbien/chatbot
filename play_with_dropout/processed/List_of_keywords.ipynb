# %%
DIRECT_VARIABLE = ['vitesse', 'batterie', 'position', 'km', 'carburant']
TIME = []
GEOGRAPHY = ['Lyon', 'hors lyon', 'paris', 'l\'étranger','france' , 'hors la france']
BORDE = {'MAX': ['plus grand', 'plus grande', 'plus grands', 
         'plus grandes',  'moin faible', 'moins faibles',
         'plus vite', 'max', 'maximum', 'maximal', 'maximaux', 'maximale',
        'plus haut', 'plus haute', 'plus hautes', 'plus hauts',  
        'plus élevé', 'plus élevée', 'plus élevés', 'plus élevées'], 
         'MIN':['moins grand', 'moins grande', 'moins grands','moins grandes',
        'plus petit', 'plus petite', 'plus petits', 'plus petites','plus faible', 'plus faibles', 
         'min', 'minimal', 'minimale', 'minimales', 'minimaux','moins vite', 
         'moins élevé', 'moins élevée', 'moins élevés', 'moins élevées'],
        'MOYENNE': ['moyenne', 'moyen', 'moyennement']
        }
COMPLEX_ANALYSIS_1 = ['problème', 'problèmes', 'erreurs', 'erreur', 'danger', 'urgence']
COMPLEX_ANALYSIS_2 = ['éco_conduite', 'vin', 'combien', 'nb_véhicules']
VARIABLE_TYPIQUE = ['à_l\'arrêt', 'en_route','polution', '']
PAIRS = []
question_for_simulation = ['quels véhicules ont', 'quel véhicule', 'quelle voiture', 'quelles voitures']
reponse_for_simulation = 'véhicule'
for borde in BORDE:
    for word in BORDE[borde]:
        for direct_variable in DIRECT_VARIABLE:
            for question_f_s in question_for_simulation:
                if direct_variable !='position':
                      question= question_f_s+' '+direct_variable + ' '+ word
                      key0 = '#id#'
                      key1 = '#'+direct_variable+'#'
                      key2 = '#'+borde +'#'
                      reponse = reponse_for_simulation +' '+key0+ ' '+ key1+ ' '+ key2
                      PAIRS.append([question,reponse])

question_for_simulation = ['', 'quel véhicule a', 'quelle voiture a', 'quelles voitures ont', 'il y a']
reponse_for_simulation = 'véhicule' 
for direct_variable in DIRECT_VARIABLE:
    for complex_analysis in COMPLEX_ANALYSIS:
            for question_f_s in question_for_simulation:
                #if direct_variable !='position':
                      question= question_f_s+' '+complex_analysis + ' '+ direct_variable
                      key0 = '#id#'
                      key1 = '#'+direct_variable+'#'
                      key2 = '#'+ complex_analysis +'#'
                      reponse = reponse_for_simulation +' '+key0+ ' '+ key2 +' '+ key1
                      PAIRS.append([question,reponse])

# %%
for i in PAIRS:
    print(i)
# Out:
# ['quels véhicules ont vitesse plus grand', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus grand', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus grand', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus grand', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus grand', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus grand', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus grand', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus grand', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus grand', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus grand', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus grand', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus grand', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus grande', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus grande', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus grande', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus grande', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus grande', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus grande', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus grande', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus grande', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus grande', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus grande', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus grande', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus grande', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus grands', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus grands', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus grands', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus grands', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus grands', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus grands', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus grands', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus grands', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus grands', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus grands', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus grands', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus grands', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus grandes', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus grandes', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus grandes', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus grandes', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus grandes', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus grandes', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus grandes', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus grandes', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus grandes', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus grandes', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus grandes', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus grandes', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse moin faible', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse moin faible', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse moin faible', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse moin faible', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie moin faible', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie moin faible', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie moin faible', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie moin faible', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km moin faible', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km moin faible', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km moin faible', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km moin faible', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse moins faibles', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse moins faibles', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse moins faibles', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse moins faibles', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie moins faibles', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie moins faibles', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie moins faibles', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie moins faibles', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km moins faibles', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km moins faibles', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km moins faibles', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km moins faibles', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus vite', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus vite', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus vite', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus vite', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus vite', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus vite', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus vite', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus vite', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus vite', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus vite', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus vite', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus vite', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse max', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse max', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse max', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse max', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie max', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie max', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie max', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie max', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km max', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km max', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km max', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km max', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse maximum', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse maximum', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse maximum', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse maximum', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie maximum', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie maximum', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie maximum', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie maximum', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km maximum', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km maximum', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km maximum', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km maximum', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse maximal', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse maximal', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse maximal', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse maximal', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie maximal', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie maximal', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie maximal', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie maximal', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km maximal', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km maximal', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km maximal', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km maximal', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse maximaux', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse maximaux', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse maximaux', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse maximaux', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie maximaux', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie maximaux', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie maximaux', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie maximaux', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km maximaux', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km maximaux', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km maximaux', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km maximaux', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse maximale', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse maximale', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse maximale', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse maximale', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie maximale', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie maximale', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie maximale', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie maximale', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km maximale', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km maximale', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km maximale', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km maximale', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus haut', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus haut', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus haut', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus haut', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus haut', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus haut', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus haut', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus haut', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus haut', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus haut', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus haut', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus haut', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus haute', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus haute', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus haute', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus haute', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus haute', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus haute', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus haute', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus haute', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus haute', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus haute', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus haute', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus haute', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus hautes', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus hautes', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus hautes', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus hautes', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus hautes', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus hautes', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus hautes', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus hautes', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus hautes', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus hautes', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus hautes', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus hautes', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus hauts', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus hauts', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus hauts', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus hauts', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus hauts', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus hauts', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus hauts', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus hauts', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus hauts', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus hauts', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus hauts', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus hauts', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus élevé', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus élevé', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus élevé', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus élevé', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus élevé', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus élevé', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus élevé', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus élevé', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus élevé', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus élevé', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus élevé', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus élevé', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus élevée', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus élevée', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus élevée', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus élevée', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus élevée', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus élevée', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus élevée', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus élevée', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus élevée', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus élevée', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus élevée', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus élevée', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus élevés', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus élevés', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus élevés', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus élevés', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus élevés', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus élevés', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus élevés', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus élevés', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus élevés', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus élevés', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus élevés', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus élevés', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse plus élevées', 'véhicule #id# #vitesse# #MAX#']
# ['quel véhicule vitesse plus élevées', 'véhicule #id# #vitesse# #MAX#']
# ['quelle voiture vitesse plus élevées', 'véhicule #id# #vitesse# #MAX#']
# ['quelles voitures vitesse plus élevées', 'véhicule #id# #vitesse# #MAX#']
# ['quels véhicules ont batterie plus élevées', 'véhicule #id# #batterie# #MAX#']
# ['quel véhicule batterie plus élevées', 'véhicule #id# #batterie# #MAX#']
# ['quelle voiture batterie plus élevées', 'véhicule #id# #batterie# #MAX#']
# ['quelles voitures batterie plus élevées', 'véhicule #id# #batterie# #MAX#']
# ['quels véhicules ont km plus élevées', 'véhicule #id# #km# #MAX#']
# ['quel véhicule km plus élevées', 'véhicule #id# #km# #MAX#']
# ['quelle voiture km plus élevées', 'véhicule #id# #km# #MAX#']
# ['quelles voitures km plus élevées', 'véhicule #id# #km# #MAX#']
# ['quels véhicules ont vitesse moins grand', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins grand', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins grand', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins grand', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins grand', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins grand', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins grand', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins grand', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins grand', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins grand', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins grand', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins grand', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins grande', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins grande', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins grande', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins grande', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins grande', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins grande', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins grande', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins grande', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins grande', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins grande', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins grande', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins grande', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins grands', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins grands', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins grands', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins grands', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins grands', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins grands', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins grands', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins grands', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins grands', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins grands', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins grands', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins grands', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins grandes', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins grandes', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins grandes', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins grandes', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins grandes', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins grandes', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins grandes', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins grandes', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins grandes', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins grandes', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins grandes', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins grandes', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse plus petit', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse plus petit', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse plus petit', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse plus petit', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie plus petit', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie plus petit', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie plus petit', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie plus petit', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km plus petit', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km plus petit', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km plus petit', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km plus petit', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse plus petite', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse plus petite', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse plus petite', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse plus petite', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie plus petite', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie plus petite', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie plus petite', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie plus petite', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km plus petite', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km plus petite', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km plus petite', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km plus petite', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse plus petits', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse plus petits', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse plus petits', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse plus petits', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie plus petits', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie plus petits', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie plus petits', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie plus petits', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km plus petits', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km plus petits', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km plus petits', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km plus petits', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse plus petites', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse plus petites', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse plus petites', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse plus petites', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie plus petites', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie plus petites', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie plus petites', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie plus petites', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km plus petites', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km plus petites', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km plus petites', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km plus petites', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse plus faible', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse plus faible', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse plus faible', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse plus faible', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie plus faible', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie plus faible', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie plus faible', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie plus faible', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km plus faible', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km plus faible', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km plus faible', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km plus faible', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse plus faibles', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse plus faibles', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse plus faibles', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse plus faibles', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie plus faibles', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie plus faibles', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie plus faibles', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie plus faibles', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km plus faibles', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km plus faibles', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km plus faibles', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km plus faibles', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse min', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse min', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse min', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse min', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie min', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie min', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie min', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie min', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km min', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km min', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km min', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km min', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse minimal', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse minimal', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse minimal', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse minimal', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie minimal', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie minimal', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie minimal', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie minimal', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km minimal', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km minimal', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km minimal', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km minimal', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse minimale', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse minimale', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse minimale', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse minimale', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie minimale', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie minimale', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie minimale', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie minimale', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km minimale', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km minimale', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km minimale', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km minimale', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse minimales', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse minimales', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse minimales', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse minimales', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie minimales', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie minimales', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie minimales', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie minimales', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km minimales', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km minimales', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km minimales', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km minimales', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse minimaux', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse minimaux', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse minimaux', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse minimaux', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie minimaux', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie minimaux', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie minimaux', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie minimaux', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km minimaux', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km minimaux', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km minimaux', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km minimaux', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins vite', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins vite', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins vite', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins vite', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins vite', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins vite', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins vite', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins vite', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins vite', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins vite', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins vite', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins vite', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins élevé', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins élevé', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins élevé', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins élevé', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins élevé', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins élevé', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins élevé', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins élevé', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins élevé', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins élevé', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins élevé', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins élevé', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins élevée', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins élevée', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins élevée', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins élevée', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins élevée', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins élevée', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins élevée', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins élevée', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins élevée', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins élevée', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins élevée', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins élevée', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins élevés', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins élevés', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins élevés', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins élevés', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins élevés', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins élevés', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins élevés', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins élevés', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins élevés', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins élevés', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins élevés', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins élevés', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moins élevées', 'véhicule #id# #vitesse# #MIN#']
# ['quel véhicule vitesse moins élevées', 'véhicule #id# #vitesse# #MIN#']
# ['quelle voiture vitesse moins élevées', 'véhicule #id# #vitesse# #MIN#']
# ['quelles voitures vitesse moins élevées', 'véhicule #id# #vitesse# #MIN#']
# ['quels véhicules ont batterie moins élevées', 'véhicule #id# #batterie# #MIN#']
# ['quel véhicule batterie moins élevées', 'véhicule #id# #batterie# #MIN#']
# ['quelle voiture batterie moins élevées', 'véhicule #id# #batterie# #MIN#']
# ['quelles voitures batterie moins élevées', 'véhicule #id# #batterie# #MIN#']
# ['quels véhicules ont km moins élevées', 'véhicule #id# #km# #MIN#']
# ['quel véhicule km moins élevées', 'véhicule #id# #km# #MIN#']
# ['quelle voiture km moins élevées', 'véhicule #id# #km# #MIN#']
# ['quelles voitures km moins élevées', 'véhicule #id# #km# #MIN#']
# ['quels véhicules ont vitesse moyenne', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quel véhicule vitesse moyenne', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quelle voiture vitesse moyenne', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quelles voitures vitesse moyenne', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quels véhicules ont batterie moyenne', 'véhicule #id# #batterie# #MOYENNE#']
# ['quel véhicule batterie moyenne', 'véhicule #id# #batterie# #MOYENNE#']
# ['quelle voiture batterie moyenne', 'véhicule #id# #batterie# #MOYENNE#']
# ['quelles voitures batterie moyenne', 'véhicule #id# #batterie# #MOYENNE#']
# ['quels véhicules ont km moyenne', 'véhicule #id# #km# #MOYENNE#']
# ['quel véhicule km moyenne', 'véhicule #id# #km# #MOYENNE#']
# ['quelle voiture km moyenne', 'véhicule #id# #km# #MOYENNE#']
# ['quelles voitures km moyenne', 'véhicule #id# #km# #MOYENNE#']
# ['quels véhicules ont vitesse moyen', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quel véhicule vitesse moyen', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quelle voiture vitesse moyen', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quelles voitures vitesse moyen', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quels véhicules ont batterie moyen', 'véhicule #id# #batterie# #MOYENNE#']
# ['quel véhicule batterie moyen', 'véhicule #id# #batterie# #MOYENNE#']
# ['quelle voiture batterie moyen', 'véhicule #id# #batterie# #MOYENNE#']
# ['quelles voitures batterie moyen', 'véhicule #id# #batterie# #MOYENNE#']
# ['quels véhicules ont km moyen', 'véhicule #id# #km# #MOYENNE#']
# ['quel véhicule km moyen', 'véhicule #id# #km# #MOYENNE#']
# ['quelle voiture km moyen', 'véhicule #id# #km# #MOYENNE#']
# ['quelles voitures km moyen', 'véhicule #id# #km# #MOYENNE#']
# ['quels véhicules ont vitesse moyennement', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quel véhicule vitesse moyennement', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quelle voiture vitesse moyennement', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quelles voitures vitesse moyennement', 'véhicule #id# #vitesse# #MOYENNE#']
# ['quels véhicules ont batterie moyennement', 'véhicule #id# #batterie# #MOYENNE#']
# ['quel véhicule batterie moyennement', 'véhicule #id# #batterie# #MOYENNE#']
# ['quelle voiture batterie moyennement', 'véhicule #id# #batterie# #MOYENNE#']
# ['quelles voitures batterie moyennement', 'véhicule #id# #batterie# #MOYENNE#']
# ['quels véhicules ont km moyennement', 'véhicule #id# #km# #MOYENNE#']
# ['quel véhicule km moyennement', 'véhicule #id# #km# #MOYENNE#']
# ['quelle voiture km moyennement', 'véhicule #id# #km# #MOYENNE#']
# ['quelles voitures km moyennement', 'véhicule #id# #km# #MOYENNE#']
# [' problème vitesse', 'véhicule #id# #problème# #vitesse#']
# ['quel véhicule a problème vitesse', 'véhicule #id# #problème# #vitesse#']
# ['quelle voiture a problème vitesse', 'véhicule #id# #problème# #vitesse#']
# ['quelles voitures ont problème vitesse', 'véhicule #id# #problème# #vitesse#']
# ['il y a problème vitesse', 'véhicule #id# #problème# #vitesse#']
# [' problèmes vitesse', 'véhicule #id# #problèmes# #vitesse#']
# ['quel véhicule a problèmes vitesse', 'véhicule #id# #problèmes# #vitesse#']
# ['quelle voiture a problèmes vitesse', 'véhicule #id# #problèmes# #vitesse#']
# ['quelles voitures ont problèmes vitesse', 'véhicule #id# #problèmes# #vitesse#']
# ['il y a problèmes vitesse', 'véhicule #id# #problèmes# #vitesse#']
# [' erreurs vitesse', 'véhicule #id# #erreurs# #vitesse#']
# ['quel véhicule a erreurs vitesse', 'véhicule #id# #erreurs# #vitesse#']
# ['quelle voiture a erreurs vitesse', 'véhicule #id# #erreurs# #vitesse#']
# ['quelles voitures ont erreurs vitesse', 'véhicule #id# #erreurs# #vitesse#']
# ['il y a erreurs vitesse', 'véhicule #id# #erreurs# #vitesse#']
# [' erreur vitesse', 'véhicule #id# #erreur# #vitesse#']
# ['quel véhicule a erreur vitesse', 'véhicule #id# #erreur# #vitesse#']
# ['quelle voiture a erreur vitesse', 'véhicule #id# #erreur# #vitesse#']
# ['quelles voitures ont erreur vitesse', 'véhicule #id# #erreur# #vitesse#']
# ['il y a erreur vitesse', 'véhicule #id# #erreur# #vitesse#']
# [' danger vitesse', 'véhicule #id# #danger# #vitesse#']
# ['quel véhicule a danger vitesse', 'véhicule #id# #danger# #vitesse#']
# ['quelle voiture a danger vitesse', 'véhicule #id# #danger# #vitesse#']
# ['quelles voitures ont danger vitesse', 'véhicule #id# #danger# #vitesse#']
# ['il y a danger vitesse', 'véhicule #id# #danger# #vitesse#']
# [' problème batterie', 'véhicule #id# #problème# #batterie#']
# ['quel véhicule a problème batterie', 'véhicule #id# #problème# #batterie#']
# ['quelle voiture a problème batterie', 'véhicule #id# #problème# #batterie#']
# ['quelles voitures ont problème batterie', 'véhicule #id# #problème# #batterie#']
# ['il y a problème batterie', 'véhicule #id# #problème# #batterie#']
# [' problèmes batterie', 'véhicule #id# #problèmes# #batterie#']
# ['quel véhicule a problèmes batterie', 'véhicule #id# #problèmes# #batterie#']
# ['quelle voiture a problèmes batterie', 'véhicule #id# #problèmes# #batterie#']
# ['quelles voitures ont problèmes batterie', 'véhicule #id# #problèmes# #batterie#']
# ['il y a problèmes batterie', 'véhicule #id# #problèmes# #batterie#']
# [' erreurs batterie', 'véhicule #id# #erreurs# #batterie#']
# ['quel véhicule a erreurs batterie', 'véhicule #id# #erreurs# #batterie#']
# ['quelle voiture a erreurs batterie', 'véhicule #id# #erreurs# #batterie#']
# ['quelles voitures ont erreurs batterie', 'véhicule #id# #erreurs# #batterie#']
# ['il y a erreurs batterie', 'véhicule #id# #erreurs# #batterie#']
# [' erreur batterie', 'véhicule #id# #erreur# #batterie#']
# ['quel véhicule a erreur batterie', 'véhicule #id# #erreur# #batterie#']
# ['quelle voiture a erreur batterie', 'véhicule #id# #erreur# #batterie#']
# ['quelles voitures ont erreur batterie', 'véhicule #id# #erreur# #batterie#']
# ['il y a erreur batterie', 'véhicule #id# #erreur# #batterie#']
# [' danger batterie', 'véhicule #id# #danger# #batterie#']
# ['quel véhicule a danger batterie', 'véhicule #id# #danger# #batterie#']
# ['quelle voiture a danger batterie', 'véhicule #id# #danger# #batterie#']
# ['quelles voitures ont danger batterie', 'véhicule #id# #danger# #batterie#']
# ['il y a danger batterie', 'véhicule #id# #danger# #batterie#']
# [' problème position', 'véhicule #id# #problème# #position#']
# ['quel véhicule a problème position', 'véhicule #id# #problème# #position#']
# ['quelle voiture a problème position', 'véhicule #id# #problème# #position#']
# ['quelles voitures ont problème position', 'véhicule #id# #problème# #position#']
# ['il y a problème position', 'véhicule #id# #problème# #position#']
# [' problèmes position', 'véhicule #id# #problèmes# #position#']
# ['quel véhicule a problèmes position', 'véhicule #id# #problèmes# #position#']
# ['quelle voiture a problèmes position', 'véhicule #id# #problèmes# #position#']
# ['quelles voitures ont problèmes position', 'véhicule #id# #problèmes# #position#']
# ['il y a problèmes position', 'véhicule #id# #problèmes# #position#']
# [' erreurs position', 'véhicule #id# #erreurs# #position#']
# ['quel véhicule a erreurs position', 'véhicule #id# #erreurs# #position#']
# ['quelle voiture a erreurs position', 'véhicule #id# #erreurs# #position#']
# ['quelles voitures ont erreurs position', 'véhicule #id# #erreurs# #position#']
# ['il y a erreurs position', 'véhicule #id# #erreurs# #position#']
# [' erreur position', 'véhicule #id# #erreur# #position#']
# ['quel véhicule a erreur position', 'véhicule #id# #erreur# #position#']
# ['quelle voiture a erreur position', 'véhicule #id# #erreur# #position#']
# ['quelles voitures ont erreur position', 'véhicule #id# #erreur# #position#']
# ['il y a erreur position', 'véhicule #id# #erreur# #position#']
# [' danger position', 'véhicule #id# #danger# #position#']
# ['quel véhicule a danger position', 'véhicule #id# #danger# #position#']
# ['quelle voiture a danger position', 'véhicule #id# #danger# #position#']
# ['quelles voitures ont danger position', 'véhicule #id# #danger# #position#']
# ['il y a danger position', 'véhicule #id# #danger# #position#']
# [' problème km', 'véhicule #id# #problème# #km#']
# ['quel véhicule a problème km', 'véhicule #id# #problème# #km#']
# ['quelle voiture a problème km', 'véhicule #id# #problème# #km#']
# ['quelles voitures ont problème km', 'véhicule #id# #problème# #km#']
# ['il y a problème km', 'véhicule #id# #problème# #km#']
# [' problèmes km', 'véhicule #id# #problèmes# #km#']
# ['quel véhicule a problèmes km', 'véhicule #id# #problèmes# #km#']
# ['quelle voiture a problèmes km', 'véhicule #id# #problèmes# #km#']
# ['quelles voitures ont problèmes km', 'véhicule #id# #problèmes# #km#']
# ['il y a problèmes km', 'véhicule #id# #problèmes# #km#']
# [' erreurs km', 'véhicule #id# #erreurs# #km#']
# ['quel véhicule a erreurs km', 'véhicule #id# #erreurs# #km#']
# ['quelle voiture a erreurs km', 'véhicule #id# #erreurs# #km#']
# ['quelles voitures ont erreurs km', 'véhicule #id# #erreurs# #km#']
# ['il y a erreurs km', 'véhicule #id# #erreurs# #km#']
# [' erreur km', 'véhicule #id# #erreur# #km#']
# ['quel véhicule a erreur km', 'véhicule #id# #erreur# #km#']
# ['quelle voiture a erreur km', 'véhicule #id# #erreur# #km#']
# ['quelles voitures ont erreur km', 'véhicule #id# #erreur# #km#']
# ['il y a erreur km', 'véhicule #id# #erreur# #km#']
# [' danger km', 'véhicule #id# #danger# #km#']
# ['quel véhicule a danger km', 'véhicule #id# #danger# #km#']
# ['quelle voiture a danger km', 'véhicule #id# #danger# #km#']
# ['quelles voitures ont danger km', 'véhicule #id# #danger# #km#']
# ['il y a danger km', 'véhicule #id# #danger# #km#']

# %%
len(QUESTION_REPONSE)
# Out:
# 504
