# %% [markdown]
# modèle n'est pas bon, ce peut être la faute de quelque fonction comme sampled_softmax_loss() dans model.
# De toute façon, le modèle est plus lourd que ce lui de Torch
# Tester pour:
# hidden_size = 40, layer =3, sample_size = 200 accuracy = 17%
# hidden_size = 40, layer =3, sample_size = DEC_VOCAB-1, accuracy = 27%

# %%
from __future__ import division
from __future__ import print_function

import argparse
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import random
import sys
import time
import math

import numpy as np
import tensorflow as tf

from model_70_1 import ChatBotModel
import config_tf as config
import data

import matplotlib.pyplot as plt


def run_step(sess, model, encoder_inputs, decoder_inputs,
             decoder_masks, bucket_id, forward_only):
    encoder_size, decoder_size = config.BUCKETS[bucket_id]
    input_feed = {}
    for step in range(encoder_size):
        input_feed[model.encoder_inputs[step].name] = encoder_inputs[step]
    for step in range(decoder_size):
        input_feed[model.decoder_inputs[step].name] = decoder_inputs[step]
        input_feed[model.decoder_masks[step].name] = decoder_masks[step]
    
    last_target = model.decoder_inputs[decoder_size].name
    input_feed[last_target] = np.zeros([model.batch_size], dtype=np.int32)
    if not forward_only:
        output_feed = [model.train_ops[bucket_id],  # update op that does SGD.
                       model.gradient_norms[bucket_id],  # gradient norm.
                       model.losses[bucket_id]]  # loss for this batch.
    else:
        output_feed = [model.losses[bucket_id]]  # loss for this batch.
        for step in range(decoder_size):  # output logits.
            output_feed.append(model.outputs[bucket_id][step])
    outputs = sess.run(output_feed, input_feed)
    if not forward_only:
        return outputs[1], outputs[2], None  # Gradient norm, loss, no outputs.
    else:
        return None, outputs[0], outputs[1:]  # No gradient norm, loss, outputs.

def _get_data(train=True):
    
    #enc_vocab, dec_vocab, inv_enc_vocab, inv_dec_vocab = build_vocab()
    if train:
          DATA = data.load_data('train_question.txt', 'train_answer.txt', inv_enc_vocab, inv_dec_vocab)
    else:
          DATA = data.load_data('test_question.txt', 'test_answer.txt', inv_enc_vocab, inv_dec_vocab)                              
    return  DATA

def _get_skip_step(n_iters):
    """ How many steps should the model train before it saves all the weights. """

    return int(n_iters/10)

def _check_restore_parameters(sess, saver):
    """ Restore the previously trained parameters if there are any. """
    ckpt = tf.train.get_checkpoint_state(os.path.dirname(config.CPT_PATH_40_2 + '/checkpoint'))
    if ckpt and ckpt.model_checkpoint_path:
        print("Loading parameters for the Chatbot")
        saver.restore(sess, ckpt.model_checkpoint_path)
    else:
        print("Initializing fresh parameters for the Chatbot")



def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

def train(n_iters, lr = config.LR):
    """ Train the bot """
    data_buckets = training_data
    tf.reset_default_graph() 
    model = ChatBotModel(False, config.BATCH_SIZE, lr = lr)
    model.build_graph()

    saver = tf.train.Saver()

    with tf.Session() as sess:
        print('Running session')
        sess.run(tf.global_variables_initializer())
        _check_restore_parameters(sess, saver)

        iteration = model.global_step.eval()
        total_loss = 0
        step =0
        loss_print = []
        bucket_id = 0
        start = time.time()
        while step < n_iters:
            step+=1
            skip_step = _get_skip_step(n_iters)
            encoder_inputs, decoder_inputs, decoder_masks = data.get_batch(data_buckets, 
                                                                           bucket_id,
                                                                           batch_size=config.BATCH_SIZE)
            
            _, step_loss, _ = run_step(sess, model, encoder_inputs, 
                                       decoder_inputs, decoder_masks, bucket_id, False)
            total_loss += step_loss
            iteration += 1
            if iteration % skip_step == 0:  
                print_loss_avg = total_loss / skip_step
                total_loss = 0
                print('%s (%d %d%%) %.4f' % (timeSince(start, step / n_iters),
                                         iteration, step / n_iters * 100, print_loss_avg))
                total_loss = 0
                loss_print.append(step_loss)
        saver.save(sess, os.path.join(config.CPT_PATH_40_2, 'chatbot'), global_step=model.global_step)
        sys.stdout.flush()
        plt.plot(loss_print)
        plt.show()

def _get_user_input():
    t = input('Vous:  ')
    return t

def _construct_reponse(output_logits, dec_vocab):
    outputs = [int(np.argmax(logit, axis=1)) for logit in output_logits]
    if config.EOS_ID in outputs:
        outputs = outputs[:outputs.index(config.EOS_ID)]

    return " ".join([tf.compat.as_str(dec_vocab[output]) for output in outputs])

def chat():
    _, enc_vocab = data.load_vocab(os.path.join(config.PROCESSED_PATH, 'encoder_vocab.txt'))
    inv_dec_vocab, _= data.load_vocab(os.path.join(config.PROCESSED_PATH, 'decoder_vocab.txt'))
    tf.reset_default_graph() 
    model = ChatBotModel(True, batch_size=1)
    model.build_graph()

    saver = tf.train.Saver()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        _check_restore_parameters(sess, saver)
        output_file = open(os.path.join(config.PROCESSED_PATH, config.OUTPUT_FILE), 'a+')
        max_length = config.BUCKETS[-1][0]
        print('Bonjour, dites moi ce que vous voulez: ')
        while True:
            line = _get_user_input()
            if len(line) > 0 and line[-1] == '\n':
                line = line[:-1]
            if line == '':
                break
            output_file.write('VOUS ++++ ' + line + '\n')
            token_ids = data.sentence2id(enc_vocab, str(line))
            if (len(token_ids) > max_length):
                print('La longueur maximale est:', max_length)
                continue
            bucket_id = _find_right_bucket(len(token_ids))
            encoder_inputs, decoder_inputs, decoder_masks = data.get_batch([(token_ids, [])], 
                                                                            bucket_id,
                                                                            batch_size=1)
            _, _, output_logits = run_step(sess, model, encoder_inputs, decoder_inputs,
                                           decoder_masks, bucket_id, True)
            response = _construct_reponse(output_logits, dec_vocab)
            
            print('Bot de AVICEN:  ', response)
            output_file.write('BOT ++++ ' + response + '\n')
        output_file.write('=============================================\n')
        output_file.close()
        
def evaluate_randomly(n_iters=300, test=True):
    if not test:
        tf.reset_default_graph() 
        model = ChatBotModel(True, batch_size=1)
        model.build_graph()
        saver = tf.train.Saver()
        list_print_random = random.sample(range(n_iters), 20)
        total_loss = 0
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            _check_restore_parameters(sess, saver)
            for i in range(n_iters):
                random_index = random.choice(range(len(training_data)))
                bucket_id = 0  
                question = training_data[random_index][0]
                answer = training_data[random_index][1]
                encoder_inputs, decoder_inputs, decoder_masks = \
                    data.get_batch([(question, [])], \
                    bucket_id, batch_size=1)
                _, _, output_logits = run_step(sess, model, encoder_inputs, decoder_inputs,
                                           decoder_masks, bucket_id, True)
                reponse = _construct_reponse(output_logits, dec_vocab)
                bonne_reponse = " ".join([str(dec_vocab[id]) for id in answer])
                question = " ".join([str(enc_vocab[id]) for id in question])
                loss = _evaluate_by_right_word(reponse, bonne_reponse)
                total_loss +=loss
                if i in list_print_random:
                    print('--------------------------------------------------')
                    print('Question:  ',  question)
                    print('Bot     :  ', reponse)
                    print('Réponse: {}  ACCURACY {}'.format(bonne_reponse, 1-loss))
        print('Test on {} sentences in train set with accuracy {}'.format(n_iters,1- total_loss/n_iters))
    else:
        tf.reset_default_graph() 
        model = ChatBotModel(True, batch_size=1)
        model.build_graph()
        saver = tf.train.Saver()
        total_loss = 0
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            _check_restore_parameters(sess, saver)
            n_iters = len(test_data)
            print_random_index = random.sample(range(n_iters), 20)
            bucket_id = 0
            for i in range(n_iters):
                question = test_data[i][0]
                answer = test_data[i][1]
                encoder_inputs, decoder_inputs, decoder_masks = data.get_batch([(question, [])], 
                                                                            bucket_id,
                                                                            batch_size=1)
                _, _, output_logits = run_step(sess, model, encoder_inputs, decoder_inputs,
                                           decoder_masks, bucket_id, True)
                reponse = _construct_reponse(output_logits, dec_vocab)
                bonne_reponse = " ".join([str(dec_vocab[id]) for id in answer[1:-1]])
                loss = _evaluate_by_right_word(reponse, bonne_reponse)
                total_loss +=loss
                if i in print_random_index:
                    question = " ".join([str(enc_vocab[id]) for id in question])
                    print('Question: ', question)
                    print('Reponse: ', reponse)
                    print('Bonne Reponse: {}. ACCURACY {:.1f} '.format(bonne_reponse,1-loss))
                    print('-'*50)
        print('Test on {} sentences'.format(n_iters))
        print('Accuracy by percent of true words {}'.format(1-total_loss/n_iters))
        #return loss/n_iters

def _evaluate_by_right_word(reponse, bonne_reponse):
    reponse = reponse.split()
    bonne_reponse = bonne_reponse.split()
    min_length = min(len(reponse), len(bonne_reponse))
    max_length = max(len(reponse), len(bonne_reponse))
    error = max_length-min_length
    for i in range(min_length):
        if reponse[i] != bonne_reponse[i]:
            error +=1
    return error/max_length

if __name__ =='__main__':
    try:
        training_data
    except NameError:
        enc_vocab, dec_vocab, inv_enc_vocab, inv_dec_vocab = data.build_vocab()
        training_data = _get_data(True)
        test_data = _get_data(False)

# %%
train(50000)
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# Time: 38.556243658065796
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Running session
# Loading parameters for the Chatbot
# INFO:tensorflow:Restoring parameters from checkpoints_40_2/chatbot-53000
# 17m 31s (- 420m 26s) (55000 4%) 0.0031
# 58m 1s (- 356m 26s) (60000 14%) 0.0068
# 83m 50s (- 265m 30s) (65000 24%) 0.0056
# 106m 56s (- 207m 35s) (70000 34%) 0.0052
# 129m 52s (- 165m 17s) (75000 44%) 0.0048
# 152m 34s (- 129m 58s) (80000 54%) 0.0045
# 175m 17s (- 98m 36s) (85000 64%) 0.0042
# 197m 56s (- 69m 32s) (90000 74%) 0.0040
# 220m 33s (- 42m 0s) (95000 84%) 0.0045
# 243m 19s (- 15m 31s) (100000 94%) 0.0039

# %%
train(1000)
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# Time: 1.955793857574463
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Running session
# Loading parameters for the Chatbot
# INFO:tensorflow:Restoring parameters from checkpoints_40_2/chatbot-103000
# 0m 45s (- 6m 50s) (103100 10%) 0.0037
# 1m 16s (- 5m 7s) (103200 20%) 0.0029
# 1m 50s (- 4m 18s) (103300 30%) 0.0039
# 2m 28s (- 3m 42s) (103400 40%) 0.0048
# 3m 5s (- 3m 5s) (103500 50%) 0.0037
# 3m 41s (- 2m 27s) (103600 60%) 0.0045
# 4m 18s (- 1m 50s) (103700 70%) 0.0028
# 4m 55s (- 1m 13s) (103800 80%) 0.0038
# 5m 33s (- 0m 37s) (103900 90%) 0.0036
# 6m 13s (- 0m 0s) (104000 100%) 0.0021

# %%
evaluate_randomly(test = False)
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# Time: 1.9719195365905762
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Loading parameters for the Chatbot
# INFO:tensorflow:Restoring parameters from checkpoints_40_2/chatbot-103000
# --------------------------------------------------
# Question:   lequel choisir
# Bot     :   dépend choisir plusieurs cela #position# de du base de données partir de avicen techniques de modifiées
# Réponse: vous pouvez choisir plusieurs modules parmi #nb_module#  ACCURACY 0.0
# --------------------------------------------------
# Question:   je veux réduire les consommations
# Bot     :   comment et toi besoin de km r&d auxquelles cf #vin_veh# la clients de vision exhaustive du
# Réponse: super comment puis-je vous aider  ACCURACY 0.0
# --------------------------------------------------
# Question:   est-ce que j'ai des problèmes de freins
# Bot     :   je suis nous disposons #vin# véhicules #vin# d'utilisation avez machine sont #vin# #vin# coffre-fort client sont
# Réponse: les informations dont nous disposons sont #vin#  ACCURACY 0.0625
# --------------------------------------------------
# Question:   je veux comparer le taux des particules fines
# Bot     :   découvrez application vous de r&d driving de diminuer l'imprimer rejets ou real driving emissions dashboard code
# Réponse: notre module #rde# pour real-driving emissions vise à mesurer les rejets d'émissions polluantes  ACCURACY 0.0
# --------------------------------------------------
# Question:   bonjour
# Bot     :   :) approximative à par détaillé quelle à de partagée tco à procédure les boîtiers conduite dit
# Réponse: social :) approximative descriptif par détaillé  ACCURACY 0.0
# --------------------------------------------------
# Question:   je veux comparer la distance parcouru par un véhicule
# Bot     :   recherche l'information notre expérience le date suis le véhicule concerné est disponible disponible sur pourquoi véhicules
# Réponse: je recherche l'information  ACCURACY 0.0
# --------------------------------------------------
# Question:   mon véhicule est il en bon état avant restitution
# Bot     :   vérifie cela besoin d'un est défaut prévue du avez connu est rude zone #vin# est disponible
# Réponse: #oui/non#  ACCURACY 0.0
# --------------------------------------------------
# Question:   il y a des problèmes
# Bot     :   vous durée vous data vous passagers vous de la émissions durée de location égale trouble déclarés
# Réponse: #oui/non#  ACCURACY 0.0
# --------------------------------------------------
# Question:   bonjour
# Bot     :   :) approximative à par détaillé quelle à de partagée tco à procédure les boîtiers conduite dit
# Réponse: bonjour  ACCURACY 0.0
# --------------------------------------------------
# Question:   quelle est la durée de l'atelier
# Bot     :   moyenne un atelier dure 2h 2h est disponible le client concerné dure voitures à 30mn le
# Réponse: en moyenne un atelier dure 2h  ACCURACY 0.0625
# --------------------------------------------------
# Question:   quel est l'état de la route
# Bot     :   dashboard cela #état_traffic# personnes formation en #adresse# de en #adresse# #adresse# #adresse# #adresse# #adresse# #adresse# #adresse#
# Réponse: le traffic est #état_traffic#  ACCURACY 0.0
# --------------------------------------------------
# Question:   je n'aime pas cette interface
# Bot     :   noté pouvez-vous préciser pourquoi quel est le véhicule véhicule boitier concerné véhicule véhicule véhicule le véhicule
# Réponse: c'est noté pouvez-vous préciser pourquoi  ACCURACY 0.0
# --------------------------------------------------
# Question:   est-ce que les pneus sont gonflés
# Bot     :   du poser administratif est réalisé dans votre coffre-fort client disponibles disponibles sur votre interface client de
# Réponse: #oui/non#  ACCURACY 0.0
# --------------------------------------------------
# Question:   quels kpi
# Bot     :   est votre besoin à procédure conduite #spec_tyre# à accessible cela n'hésitez pas à accessible client objectif
# Réponse: quel est votre besoin  ACCURACY 0.0
# --------------------------------------------------
# Question:   combien de voitures circulent
# Bot     :   de la la société roulent actuellement société roulent actuellement votre dashboard ce questions sont tes vous
# Réponse: #total_veh_movement# véhicules de la société roulent actuellement  ACCURACY 0.0
# --------------------------------------------------
# Question:   combien de kilomètres a fait ce véhicule
# Bot     :   véhicule a parcouru #km# trajet annuel roulé #km# trajet #km# #km# #km# #km# #km# #km# #km#
# Réponse: ce véhicule a effectué #km#  ACCURACY 0.0
# --------------------------------------------------
# Question:   je veux comparer le taux de nox
# Bot     :   découvrez application vous de r&d driving de diminuer polluantes module tiers driving emissions real de emissions
# Réponse: notre module #rde# pour real-driving emissions vise à mesurer les rejets d'émissions polluantes  ACCURACY 0.0
# --------------------------------------------------
# Question:   quel est le kilometrage moyen de ma flotte
# Bot     :   vérifie vous renseigner en approximative disponibles sont en zone en sont en zone tco aussi sont
# Réponse: #km_moyenne#  ACCURACY 0.0
# --------------------------------------------------
# Question:   quelles synergies
# Bot     :   synergie entre acteurs du monde professionnel est 69003 lyon lafayette est 69003 à lafayette 69003 la
# Réponse: forte synergie entre acteurs du monde professionnel  ACCURACY 0.0
# --------------------------------------------------
# Question:   le boitier est hs
# Bot     :   vous en merci des les merci pour les rejets a #list_module# à diminuer management qu'un ticket
# Réponse: nous prenons en compte cet incident merci de préciser son numéro de série  ACCURACY 0.0
# Test on 300 sentences in train set with accuracy 0.013541666666666674

# %%
evaluate_randomly()
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# Time: 2.087144374847412
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Loading parameters for the Chatbot
# INFO:tensorflow:Restoring parameters from checkpoints_40_2/chatbot-103000
# Question:  quelles sont les économies réalisées
# Reponse:  toi trouverez cela ici sont est #position# base sont certitude dans votre interface client sont of
# Bonne Reponse: avez économisé. ACCURACY 0.0
# --------------------------------------------------
# Question:  cordialement
# Reponse:  copie votre disponible dans votre contrat de sur votre contrat de sur votre véhicules 30mn de
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  merci monsieur
# Reponse:  rien un procédure rejets espace numéro ownership entre lyon fines program cours fines particules fines tous
# Bonne Reponse: rien. ACCURACY 0.1
# --------------------------------------------------
# Question:  taux de disponibilité
# Reponse:  coût un bot est votre flotte cost dans entre techniques dit pas socle de connaissances techniques
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  peut-on localisé ce véhicule
# Reponse:  de disponible sur votre au disponible prends #vin# les disponible sur le #date_fin_contrat# #tel_sav# contrat souhaitez-vous
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  quelles sont les caractéristiques techniques de ce véhicule
# Reponse:  pouvez constructeur disponibles de #priorité# connu de #vin# est indiqué dans votre interface client de #vin#
# Bonne Reponse: caractéristiques du véhicule sont. ACCURACY 0.0
# --------------------------------------------------
# Question:  je souhaite avoir un rapport
# Reponse:  idée un développée de souhaitez-vous la clients r&d de données l'imprimer concernées sur souhaitez-vous de sur
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  quelles sont les alertes
# Reponse:  temps permis disponibles sur les sur #km# store de disponibles sur le store disponibles disponibles sur
# Bonne Reponse: alertes sont. ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de véhicules connectés
# Reponse:  véhicules du immobilisé parcouru #adresse# de #adresse# #adresse# de #adresse# de #adresse# #adresse# achat de #km#
# Bonne Reponse: y a. ACCURACY 0.0
# --------------------------------------------------
# Question:  est-ce que la bonne motorisation
# Reponse:  révision aura lieu le coffre-fort d'un est toujours servir du prêt critères de toujours questions à
# Bonne Reponse: vous pouvez utiliser le module motorisation pour vous éclairer dans votre. ACCURACY 0.1
# --------------------------------------------------
# Question:  bonjour
# Reponse:  :) approximative à par détaillé quelle à de partagée tco à procédure les boîtiers conduite dit
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  est ce que mon disque de frein est abîmé
# Reponse:  de vos défaut est #geoloc# de #adresse# est véhicules immobilisé de disponibles #adresse# véhicules mois de
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de kilomètre mon véhicule a t-il parcouru aujourd’hui
# Reponse:  véhicule a dans votre l'objet d'un du #vin# l'interface achat du #vin# l'interface #cv# votre interface
# Bonne Reponse: véhicule a effectué. ACCURACY 0.1
# --------------------------------------------------
# Question:  comment ça va
# Reponse:  va les lab toi merci de préciser la véhicule concerné de votre interface client disponibles sur
# Bonne Reponse: va et. ACCURACY 0.1
# --------------------------------------------------
# Question:  cordialement
# Reponse:  copie votre disponible dans votre contrat de sur votre contrat de sur votre véhicules 30mn de
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  bonjour
# Reponse:  :) approximative à par détaillé quelle à de partagée tco à procédure les boîtiers conduite dit
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  un boîtier ne fonctionne plus
# Reponse:  consommation des livraison est le client date est qui client store constructeur correspond qui le store
# Bonne Reponse: prenons en compte cet incident quel est le boitier. ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de véhicules sont utilisés aujourd'hui
# Reponse:  moyenne votre collaborateurs de #consumption# d'un fonctionnement de développement zone administratif coffre-fort administratif de 30mn d'un
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de voitures sont immobilisées
# Reponse:  distance ce véhicule véhicule roulé #km# véhicule #km# véhicule #km# véhicule #km# véhicule #km# véhicule #km#
# Bonne Reponse: véhicule #vin# semble. ACCURACY 0.0
# --------------------------------------------------
# Question:  la flotte est comment
# Reponse:  votre demande votre espace client grise votre peut être client correcte de #durée_contrat# mois votre interface
# Bonne Reponse: vais vérifier mais pouvez-vous préciser votre. ACCURACY 0.0
# --------------------------------------------------
# Test on 136 sentences
# Accuracy by percent of true words 0.02527573529411764

# %%
#DATA = data.load_data('train_question.txt', 'train_answer.txt', inv_enc_vocab, inv_dec_vocab)
idx = random.sample(range(len(training_data)), 1)
data1 = DATA[idx[0]]
question =  [enc_vocab[ix] for ix in data1[0]]
answer = [dec_vocab[ix] for ix in data1[1]]
print(question, '   ', answer)
# Out:
# ['quel', 'est', 'le', 'contexte', 'routier']     ['quelle', 'est', 'la', 'zone', 'géographique', 'visée']
