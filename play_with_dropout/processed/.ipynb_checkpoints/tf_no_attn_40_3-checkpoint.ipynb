# %% [markdown]
# modèle n'est pas bon, ce peut être la faute de quelque fonction comme sampled_softmax_loss() dans model.
# De toute façon, le modèle est plus lourd que ce lui de Torch
# Tester pour:
# hidden_size = 40, layer =3, sample_size = 200 accuracy = 17%
# hidden_size = 40, layer =3, sample_size = DEC_VOCAB-1, accuracy = 27%

# %%
from __future__ import division
from __future__ import print_function

import argparse
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import random
import sys
import time
import math

import numpy as np
import tensorflow as tf

from tf_model import ChatBotModel
import config_tf as config
import data

import matplotlib.pyplot as plt


def run_step(sess, model, encoder_inputs, decoder_inputs,
             decoder_masks, bucket_id, forward_only):
    encoder_size, decoder_size = config.BUCKETS[bucket_id]
    input_feed = {}
    for step in range(encoder_size):
        input_feed[model.encoder_inputs[step].name] = encoder_inputs[step]
    for step in range(decoder_size):
        input_feed[model.decoder_inputs[step].name] = decoder_inputs[step]
        input_feed[model.decoder_masks[step].name] = decoder_masks[step]
    
    last_target = model.decoder_inputs[decoder_size].name
    input_feed[last_target] = np.zeros([model.batch_size], dtype=np.int32)
    if not forward_only:
        output_feed = [model.train_ops[bucket_id],  # update op that does SGD.
                       model.gradient_norms[bucket_id],  # gradient norm.
                       model.losses[bucket_id]]  # loss for this batch.
    else:
        output_feed = [model.losses[bucket_id]]  # loss for this batch.
        for step in range(decoder_size):  # output logits.
            output_feed.append(model.outputs[bucket_id][step])
    outputs = sess.run(output_feed, input_feed)
    if not forward_only:
        return outputs[1], outputs[2], None  # Gradient norm, loss, no outputs.
    else:
        return None, outputs[0], outputs[1:]  # No gradient norm, loss, outputs.

def _get_data(train=True):
    
    #enc_vocab, dec_vocab, inv_enc_vocab, inv_dec_vocab = build_vocab()
    if train:
          DATA = data.load_data('train_question.txt', 'train_answer.txt', inv_enc_vocab, inv_dec_vocab)
    else:
          DATA = data.load_data('test_question.txt', 'test_answer.txt', inv_enc_vocab, inv_dec_vocab)                              
    return  DATA

def _get_skip_step(n_iters):
    """ How many steps should the model train before it saves all the weights. """

    return int(n_iters/10)

def _check_restore_parameters(sess, saver):
    """ Restore the previously trained parameters if there are any. """
    ckpt = tf.train.get_checkpoint_state(os.path.dirname(config.CPT_PATH_40_3 + '/checkpoint'))
    if ckpt and ckpt.model_checkpoint_path:
        print("Loading parameters for the Chatbot")
        saver.restore(sess, ckpt.model_checkpoint_path)
    else:
        print("Initializing fresh parameters for the Chatbot")



def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

def train(n_iters, lr = config.LR):
    """ Train the bot """
    data_buckets = training_data
    tf.reset_default_graph() 
    model = ChatBotModel(False, config.BATCH_SIZE)
    model.build_graph()

    saver = tf.train.Saver()

    with tf.Session() as sess:
        print('Running session')
        sess.run(tf.global_variables_initializer())
        _check_restore_parameters(sess, saver)

        iteration = model.global_step.eval()
        total_loss = 0
        step =0
        loss_print = []
        bucket_id = 0
        start = time.time()
        while step < n_iters:
            step+=1
            skip_step = _get_skip_step(n_iters)
            encoder_inputs, decoder_inputs, decoder_masks = data.get_batch(data_buckets, 
                                                                           bucket_id,
                                                                           batch_size=config.BATCH_SIZE)
            
            _, step_loss, _ = run_step(sess, model, encoder_inputs, 
                                       decoder_inputs, decoder_masks, bucket_id, False)
            total_loss += step_loss
            iteration += 1
            if iteration % skip_step == 0:  
                print_loss_avg = total_loss / skip_step
                total_loss = 0
                print('%s (%d %d%%) %.4f' % (timeSince(start, step / n_iters),
                                         iteration, step / n_iters * 100, print_loss_avg))
                total_loss = 0
                loss_print.append(step_loss)
        saver.save(sess, os.path.join(config.CPT_PATH_40_3, 'chatbot'), global_step=model.global_step)
        sys.stdout.flush()
        plt.plot(loss_print)
        plt.show()

def _get_user_input():
    t = input('Vous:  ')
    return t

def _construct_reponse(output_logits, dec_vocab):
    outputs = [int(np.argmax(logit, axis=1)) for logit in output_logits]
    if config.EOS_ID in outputs:
        outputs = outputs[:outputs.index(config.EOS_ID)]

    return " ".join([tf.compat.as_str(dec_vocab[output]) for output in outputs])

def chat():
    _, enc_vocab = data.load_vocab(os.path.join(config.PROCESSED_PATH, 'encoder_vocab.txt'))
    inv_dec_vocab, _= data.load_vocab(os.path.join(config.PROCESSED_PATH, 'decoder_vocab.txt'))
    tf.reset_default_graph() 
    model = ChatBotModel(True, batch_size=1)
    model.build_graph()

    saver = tf.train.Saver()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        _check_restore_parameters(sess, saver)
        output_file = open(os.path.join(config.PROCESSED_PATH, config.OUTPUT_FILE), 'a+')
        max_length = config.BUCKETS[-1][0]
        print('Bonjour, dites moi ce que vous voulez: ')
        while True:
            line = _get_user_input()
            if len(line) > 0 and line[-1] == '\n':
                line = line[:-1]
            if line == '':
                break
            output_file.write('VOUS ++++ ' + line + '\n')
            token_ids = data.sentence2id(enc_vocab, str(line))
            if (len(token_ids) > max_length):
                print('La longueur maximale est:', max_length)
                continue
            bucket_id = _find_right_bucket(len(token_ids))
            encoder_inputs, decoder_inputs, decoder_masks = data.get_batch([(token_ids, [])], 
                                                                            bucket_id,
                                                                            batch_size=1)
            _, _, output_logits = run_step(sess, model, encoder_inputs, decoder_inputs,
                                           decoder_masks, bucket_id, True)
            response = _construct_reponse(output_logits, dec_vocab)
            
            print('Bot de AVICEN:  ', response)
            output_file.write('BOT ++++ ' + response + '\n')
        output_file.write('=============================================\n')
        output_file.close()
        
def evaluate_randomly(n_iters=300, test=True):
    if not test:
        tf.reset_default_graph() 
        model = ChatBotModel(True, batch_size=1)
        model.build_graph()
        saver = tf.train.Saver()
        list_print_random = random.sample(range(n_iters), 20)
        total_loss = 0
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            _check_restore_parameters(sess, saver)
            for i in range(n_iters):
                random_index = random.choice(range(len(training_data)))
                bucket_id = 0  
                question = training_data[random_index][0]
                answer = training_data[random_index][1]
                encoder_inputs, decoder_inputs, decoder_masks = \
                    data.get_batch([(question, [])], \
                    bucket_id, batch_size=1)
                _, _, output_logits = run_step(sess, model, encoder_inputs, decoder_inputs,
                                           decoder_masks, bucket_id, True)
                reponse = _construct_reponse(output_logits, dec_vocab)
                bonne_reponse = " ".join([str(dec_vocab[id]) for id in answer])
                question = " ".join([str(enc_vocab[id]) for id in question])
                loss = _evaluate_by_right_word(reponse, bonne_reponse)
                total_loss +=loss
                if i in list_print_random:
                    print('-'*50)
                    print('Question:  ',  question)
                    print('Bot     :  ', reponse)
                    print('Réponse: {}  ACCURACY {}'.format(bonne_reponse, 1-loss))
        print('Test on {} sentences in train set with accuracy {}'.format(n_iters,1- total_loss/n_iters))
    else:
        tf.reset_default_graph() 
        model = ChatBotModel(True, batch_size=1)
        model.build_graph()
        saver = tf.train.Saver()
        total_loss = 0
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            _check_restore_parameters(sess, saver)
            n_iters = len(test_data)
            print_random_index = random.sample(range(n_iters), 20)
            bucket_id = 0
            for i in range(n_iters):
                question = test_data[i][0]
                answer = test_data[i][1]
                encoder_inputs, decoder_inputs, decoder_masks = data.get_batch([(question, [])], 
                                                                            bucket_id,
                                                                            batch_size=1)
                _, _, output_logits = run_step(sess, model, encoder_inputs, decoder_inputs,
                                           decoder_masks, bucket_id, True)
                reponse = _construct_reponse(output_logits, dec_vocab)
                bonne_reponse = " ".join([str(dec_vocab[id]) for id in answer[1:-1]])
                loss = _evaluate_by_right_word(reponse, bonne_reponse)
                total_loss +=loss
                if i in print_random_index:
                    question = " ".join([str(enc_vocab[id]) for id in question])
                    print('Question: ', question)
                    print('Reponse: ', reponse)
                    print('Bonne Reponse: {}. ACCURACY {:.1f} '.format(bonne_reponse,1-loss))
                    print('-'*50)
        print('Test on {} sentences'.format(n_iters))
        print('Accuracy by percent of true words {}'.format(1-total_loss/n_iters))
        #return loss/n_iters

def _evaluate_by_right_word(reponse, bonne_reponse):
    reponse = reponse.split()
    bonne_reponse = bonne_reponse.split()
    min_length = min(len(reponse), len(bonne_reponse))
    max_length = max(len(reponse), len(bonne_reponse))
    error = max_length-min_length
    for i in range(min_length):
        if reponse[i] != bonne_reponse[i]:
            error +=1
    return error/max_length

def _test_data(n =20):
    list_random = random.sample(range(len(DATA)), 10)
    for i in list_random:
        pair = DATA[i]
        question = ' '.join([enc_vocab[ix] for ix in pair[0]])
        answer = ' '.join([dec_vocab[ix] for ix in pair[1]])
        print(i, ': ', question)
        print(i, ': ',answer)
        #print('-'*30)

if __name__ =='__main__':
    try:
        training_data
    except NameError:
        enc_vocab, dec_vocab, inv_enc_vocab, inv_dec_vocab = data.build_vocab()
        training_data = _get_data(True)
        test_data = _get_data(False)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# load 567 sentences from data
# load 141 sentences from data

# %%
train(10000)
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# Time: 1.865391492843628
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Running session
# Loading parameters for the Chatbot
# INFO:tensorflow:Restoring parameters from checkpoints_40_2/chatbot-43000
# 5m 9s (- 46m 25s) (44000 10%) 2.4733
# 9m 17s (- 37m 8s) (45000 20%) 0.5687
# 13m 3s (- 30m 27s) (46000 30%) 0.1347
# 15m 41s (- 23m 32s) (47000 40%) 0.0397
# 17m 45s (- 17m 45s) (48000 50%) 0.2087
# 21m 9s (- 14m 6s) (49000 60%) 0.0202
# 27m 46s (- 11m 54s) (50000 70%) 0.0135

# %%
train(50000)
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# Time: 33.610801458358765
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Running session
# Initializing fresh parameters for the Chatbot
# 45m 55s (- 413m 21s) (5000 10%) 1.8233
# 79m 12s (- 316m 51s) (10000 20%) 0.1373
# 104m 20s (- 243m 27s) (15000 30%) 0.0630
# 129m 31s (- 194m 17s) (20000 40%) 0.0093
# 154m 20s (- 154m 20s) (25000 50%) 0.0070
# 179m 3s (- 119m 22s) (30000 60%) 0.0062
# 204m 2s (- 87m 26s) (35000 70%) 0.0056
# 228m 46s (- 57m 11s) (40000 80%) 0.0052
# 253m 37s (- 28m 10s) (45000 90%) 0.0049
# 267m 16s (- 0m 0s) (50000 100%) 0.0045

# %%
evaluate_randomly(test= False)
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# Time: 2.1952006816864014
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Loading parameters for the Chatbot
# INFO:tensorflow:Restoring parameters from checkpoints_40_3/chatbot-50000
# --------------------------------------------------
# Question:   quel est le vin de ce véhicule
# Bot     :   véhicule est #vin# #vin# de #km# concerné concerné de #km# a série concerné de série de
# Réponse: ce véhicule est #vin#  ACCURACY 0.0625
# --------------------------------------------------
# Question:   je veux réduire la pollution
# Bot     :   bien faire découvrez notre module rde ou real driving emissions emissions particules fines fines fines fines
# Réponse: pour bien faire découvrez notre module rde ou real driving emissions  ACCURACY 0.0625
# --------------------------------------------------
# Question:   la puissance de ce véhicule est-elle adaptée pour faire la mission
# Bot     :   ce véhicule semble adapté à la réalisation de la mission à à dans de la certitude
# Réponse: oui ce véhicule semble adapté à la réalisation de la mission  ACCURACY 0.0
# --------------------------------------------------
# Question:   je voudrais m'inscrire à un workshop
# Bot     :   faut nous contacter mail mail vous mieux vous inscrire les eventbrite fines eventbrite fines particules fines
# Réponse: il faut nous contacter par mail ou mieux vous inscrire sur eventbrite  ACCURACY 0.0
# --------------------------------------------------
# Question:   est-ce-que tout va bien
# Bot     :   va et toi toi besoin besoin et entre et techniques connaissances connaissances techniques connaissances connaissances techniques
# Réponse: ça va et toi  ACCURACY 0.0625
# --------------------------------------------------
# Question:   tco
# Bot     :   cost of ownership ownership ownership ownership of of ownership ownership ownership ownership client client votre client
# Réponse: total cost of ownership  ACCURACY 0.0625
# --------------------------------------------------
# Question:   quels sont les indicateurs de pollution
# Bot     :   des des indicateurs de conduite sont dans #kpi_pollution# #kpi_pollution# #kpi_pollution# #kpi_pollution# tco interface interface fiche d'administration
# Réponse: la liste des indicateurs de conduite sont disponibles dans #kpi_pollution#  ACCURACY 0.0625
# --------------------------------------------------
# Question:   quel est le mode de transmission de ce véhicule
# Bot     :   tco #vin# #vin# est #km# restitution restitution fiscale #vin# #vin# #vin# #vin# a zone a été
# Réponse: #transmission#vin#  ACCURACY 0.0
# --------------------------------------------------
# Question:   les échéances sont respectées
# Bot     :   quelles échéances parlez-vous à l'immobilisation de mesurer de particules fines fines fines fines fines fines de
# Réponse: de quelles échéances parlez-vous  ACCURACY 0.0
# --------------------------------------------------
# Question:   je viens de bourg en bresse
# Bot     :   durée de votre trajet sera de #calcul_roadtrip# #calcul_roadtrip# #calcul_roadtrip# de #nb_veh# votre sur de #nb_veh# votre
# Réponse: la durée de votre trajet sera de #calcul_roadtrip#  ACCURACY 0.0625
# --------------------------------------------------
# Question:   je veux comparer le taux de nox
# Bot     :   module #rde# pour real-driving emissions vise à mesurer les rejets d'émissions polluantes polluantes polluantes fines fines
# Réponse: notre module #rde# pour real-driving emissions vise à mesurer les rejets d'émissions polluantes  ACCURACY 0.0625
# --------------------------------------------------
# Question:   si je pars cet après-midi quel véhicule prendre
# Bot     :   pouvez emprunter #list_vin_afternoon# #list_vin_afternoon# #list_vin_afternoon# #list_vin_afternoon# d'émissions d'émissions d'émissions d'émissions polluantes polluantes polluantes polluantes polluantes polluantes
# Réponse: vous pouvez emprunter #list_vin_afternoon#  ACCURACY 0.0625
# --------------------------------------------------
# Question:   combien de véhicules sont disponibles ce soir
# Bot     :   pouvez vous servir du #list_vin_tonight# le tous à l'interface l'interface client polluantes polluantes l'interface l'interface l'interface
# Réponse: vous pouvez vous servir du #list_vin_tonight#  ACCURACY 0.0
# --------------------------------------------------
# Question:   quand
# Bot     :   le #date# #date# le #date# data merci data trouble code trouble de série véhicule de véhicule
# Réponse: c'est le #date#  ACCURACY 0.0625
# --------------------------------------------------
# Question:   j'aimerais réduire mon empreinte carbone
# Bot     :   module #rde# pour real-driving emissions vise à mesurer les rejets nox de particules fines fines fines
# Réponse: notre module #rde# pour real-driving emissions vise à mesurer les rejets nox de particules fines  ACCURACY 0.0625
# --------------------------------------------------
# Question:   je souhaite avoir des données comparatives
# Bot     :   initiative initiative initiative initiative émissions véhicule véhicule concerné pouvez dashboard dashboard véhicule de #km# interface client
# Réponse: excellente initiative  ACCURACY 0.0625
# --------------------------------------------------
# Question:   combien de passagers à bord
# Bot     :   les données constructeurs vous pouvez accueillir #vin_seat# passagers passagers passagers les données les véhicules de définie
# Réponse: selon les données constructeurs vous pouvez accueillir #vin_seat# passagers  ACCURACY 0.0625
# --------------------------------------------------
# Question:   à bientôt
# Bot     :   bientôt retours note des n'hésitez ïuvre objectif objectif d’expérience corriger corriger n'hésitez #detail_module# de interpeller les
# Réponse: à bientôt  ACCURACY 0.0
# --------------------------------------------------
# Question:   je veux réduire le rejet de co2
# Bot     :   module #rde# pour real-driving émissions vise à mesurer tous les rejets d'émissions polluantes polluantes polluantes polluantes
# Réponse: notre module #rde# pour real-driving émissions vise à mesurer tous les rejets d'émissions polluantes  ACCURACY 0.0625
# --------------------------------------------------
# Question:   bonjour mademoiselle
# Bot     :   faut retours en par en allons nos nous nos les concernés les concernés les concernés de
# Réponse: bonjour  ACCURACY 0.0
# Test on 300 sentences in train set with accuracy 0.02604166666666663

# %%
evaluate_randomly()
# Out:
# Initialize new model
# Create placeholders
# Create inference
# Creating loss...
# It might take a couple of minutes depending on how many buckets you have.
# Time: 2.8833513259887695
# Create optimizer...
# It might take a couple of minutes depending on how many data  you have.
# Loading parameters for the Chatbot
# INFO:tensorflow:Restoring parameters from checkpoints_40_3/chatbot-50000
# Question:  facturation
# Reponse:  le aura d'utilisation par nous allons son son mesurer de rejets fines fines de particules de
# Bonne Reponse: pouvez vous adresser à notre service comptabilité. ACCURACY 0.0
# --------------------------------------------------
# Question:  quels sont les indicateurs disponibles
# Reponse:  des indicateurs de conduite sont disponibles dans #kpi_finance# #kpi_conduite# #kpi_conduite# tco clients administrateur #kpi_conduite# #kpi_conduite# administratif
# Bonne Reponse: liste des indicateurs sont disponibles dans. ACCURACY 0.0
# --------------------------------------------------
# Question:  quand ce véhicule est entré dans le parc
# Reponse:  date du été #cv# la #date_fin_contrat# la restitution du #vin# dans de #date_fin_contrat# mois l'usage ce
# Bonne Reponse: véhicule a rejoint le parc. ACCURACY 0.0
# --------------------------------------------------
# Question:  quels sont les véhicules immobilisés
# Reponse:  sont votre besoin sur sur le store le store #kpi_conduite# #kpi_conduite# interface interface clients #kpi_conduite# #kpi_conduite#
# Bonne Reponse: liste des véhicules arrêtés stoppés ou immobilisés est disponible dans votre. ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de kilomètres a fait ce véhicule ce mois
# Reponse:  distance parcourue #km# ce est est de #km# d'émissions parcouru #km# polluantes polluantes #km# #km# #tco_vehicule#
# Bonne Reponse: distance parcourue par ce véhicule est de. ACCURACY 0.3
# --------------------------------------------------
# Question:  bonjour monsieur
# Reponse:  #nb_véhicules# prends note plus voici pros procédure à procédure à interpeller en interpeller la zone choisi
# Bonne Reponse: madame. ACCURACY 0.0
# --------------------------------------------------
# Question:  le workshop est-il ouvert à d'autres participants
# Reponse:  module benchmark plusieurs à incident envisagez vous mesurer fines particules particules fines fines fines fines fines
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  peut-on localisé ce véhicule
# Reponse:  je parler notre est #brand_tyre# le mesurer concerné concerné nox de particules particules fines nox de
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  je viens de clermont-ferrand
# Reponse:  préciser de votre trajet sera de #calcul_roadtrip# de #calcul_roadtrip# de #calcul_roadtrip# de question votre #calcul_roadtrip# de
# Bonne Reponse: durée de votre trajet sera de. ACCURACY 0.3
# --------------------------------------------------
# Question:  quelles sont les caractéristiques techniques de ce véhicule
# Reponse:  vous durée durée sont ce #vin# tco tco l'interface l'interface l'interface client location location ce l'interface
# Bonne Reponse: caractéristiques du véhicule sont. ACCURACY 0.1
# --------------------------------------------------
# Question:  nox
# Reponse:  le #date# avec real-driving emissions emissions real pour diminuer diminuer #calcul_roadtrip# #calcul_roadtrip# #calcul_roadtrip# #calcul_roadtrip# #calcul_roadtrip# #calcul_roadtrip#
# Bonne Reponse: module #rde# pour real-driving émissions vise à mesurer les rejets nox et de particules. ACCURACY 0.1
# --------------------------------------------------
# Question:  quel carburant est le plus rentable pour ce véhicule
# Reponse:  kilométrage des semble #km# #vitesse# tco espace client d'émissions d'émissions tco tco tco #adresse# #adresse# #adresse#
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  je vais bien
# Reponse:  va de toi de #lab_program# vous inscrire de eventbrite de flotte de clients d'administration d'administration d'administration
# Bonne Reponse: je peux. ACCURACY 0.0
# --------------------------------------------------
# Question:  quand dois-je faire le prochain entretien
# Reponse:  le le été par le #date_fin_contrat# a a #vin# #vitesse# #tco_vehicule# #tco_vehicule# #tco_vehicule# #tco_vehicule# #vin# #vin#
# Bonne Reponse: je ne trouve pas l’information correspondante dans la base de. ACCURACY 0.0
# --------------------------------------------------
# Question:  je veux une voitures
# Reponse:  préciser votre demande sera de #calcul_roadtrip# renseigner renseigner dashboard client sur fines eventbrite fines eventbrite fines
# Bonne Reponse: véhicule le plus proche est. ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de véhicules sont utilisés aujourd'hui
# Reponse:  véhicules du #list_vin_free# véhicules est ce ce fiche véhicules ce véhicules tco véhicule du patientez du
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de voitures sont roulées
# Reponse:  y a semble #km# est de #vin_proxi# de particules de particules de particules de particules de
# Bonne Reponse: . ACCURACY 0.0
# --------------------------------------------------
# Question:  combien de voitures sont roulées aujourd'hui
# Reponse:  y a #total_veh_movement# véhicules est immobilisé de dans de interface client de particules de particules de
# Bonne Reponse: y a. ACCURACY 0.1
# --------------------------------------------------
# Question:  je veux des renseignements
# Reponse:  puis-je vous pour real-driving émissions vous vise vous mesurer de particules fines fines #kpi_pollution# fines particules
# Bonne Reponse: suis là pour. ACCURACY 0.1
# --------------------------------------------------
# Question:  je veux être informé de d'indisponibilité d'un véhicule
# Reponse:  s'agit souci numérique cf #vin_proxi# le dashboard parcouru location ce location location location fines location tco
# Bonne Reponse: je vous adresserai une. ACCURACY 0.0
# --------------------------------------------------
# Test on 136 sentences
# Accuracy by percent of true words 0.02757352941176472

# %%
for i in range(300):
    word = dec_vocab[i]
    if i!=inv_dec_vocab[word]:
        print(word)

# %%
DATA = _get_data()
# Out:
# load 567 sentences from data

# %%
list_random = random.sample(range(len(DATA)), 10)
for i in list_random:
    pair = DATA[i]
    question = ' '.join([enc_vocab[ix] for ix in pair[0]])
    answer = ' '.join([dec_vocab[ix] for ix in pair[1]])
    print(i, ': ', question)
    print(i, ': ',answer)
    print('-'*30)
# Out:
# 379 :  bonjour
# 379 :  bonjour
# ------------------------------
# 214 :  quel est l'historique des trajets
# 214 :  voici #histo_trip# des trajets
# ------------------------------
# 523 :  quelle est la marque des pneus
# 523 :  la marque des pneus est #brand_tyre#
# ------------------------------
# 233 :  dernière vidange
# 233 :  #last_vidange#
# ------------------------------
# 517 :  j'aimerais réduire mon empreinte carbone
# 517 :  notre module #rde# pour real-driving emissions vise à mesurer les rejets nox de particules fines
# ------------------------------
# 150 :  je peux encore m'inscrire
# 150 :  il faut nous contacter par mail ou mieux vous inscrire sur eventbrite
# ------------------------------
# 359 :  merci
# 359 :  de rien
# ------------------------------
# 499 :  la facture est disponible
# 499 :  la facture est disponible dans votre espace client
# ------------------------------
# 521 :  co2
# 521 :  notre module #rde# pour real-driving emissions vise à mesurer les rejets nox de particules fines
# ------------------------------
# 340 :  mes accélérations sont elles trop franches
# 340 :  #consommation#
# ------------------------------
